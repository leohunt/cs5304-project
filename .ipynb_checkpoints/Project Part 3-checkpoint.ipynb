# %%
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
import torchvision
import math
from torch.autograd import Variable
import copy
import torchvision.transforms as transforms

# %%
import pandas as pd 
import numpy as np

# %%
rating_dir = './RCdata/rating_final.csv'
rest_profile_dir = './RCdata/geoplaces2.csv'
rest_cuisine_dir = './RCdata/chefmozcuisine.csv'
rest_payment_dir = './RCdata/chefmozaccepts.csv'
rest_parking_dir = './RCdata/chefmozparking.csv'
user_cuisine_dir = './RCdata/usercuisine.csv'
user_payment_dir = './RCdata/userpayment.csv'
user_profile_dir = './RCdata/userprofile.csv'

# %%
rest_profile = pd.read_csv(rest_profile_dir, encoding = 'cp1252')
rest_cuisine = pd.read_csv(rest_cuisine_dir) #encoding = 'cp1252')
rest_payment = pd.read_csv(rest_payment_dir)
rest_parking = pd.read_csv(rest_parking_dir)

# %%
user_profile = pd.read_csv(user_profile_dir)
user_payment = pd.read_csv(user_payment_dir)
user_cuisine = pd.read_csv(user_cuisine_dir)

# %%
n_users = len(user_profile.userID)
print (n_users)
# Out:
# 138

# %% [markdown]
# ## Get Contexts

# %%
n_rests = len(rest_profile.placeID)
print (n_rests)
# Out:
# 130

# %%
rests = np.array(rest_profile.placeID)

# %%
cuisine_data = [0 for i in range(n_rests)]

# %%
for i in range(len(cuisine_data)):
    cuisines = rest_cuisine[rest_cuisine['placeID'] == rests[i]]['Rcuisine']
    this_one = ''
    if len(cuisines)>0: 
        for j in range(len(cuisines)):
            this_one = this_one + cuisines.iloc[j] + ' '        
    cuisine_data[i] = this_one

# %%
rest_profile.loc[:,'Cuisine'] = pd.Series(cuisine_data, index=rest_profile.index)

# %%
payment_data = [0 for i in range(n_rests)]

# %%
for i in range(len(payment_data)):
    payment = rest_payment[rest_payment['placeID'] == rests[i]]['Rpayment']
    this_one = ''
    if len(payment)>0: 
        for j in range(len(payment)):
            this_one = this_one + payment.iloc[j] + ' '        
    payment_data[i] = this_one

# %%
rest_profile.loc[:,'Payment'] = pd.Series(payment_data, index=rest_profile.index)

# %%
parking_data = [0 for i in range(n_rests)]

# %%
for i in range(len(parking_data)):
    parking = rest_parking[rest_parking['placeID'] == rests[i]]['parking_lot']
    this_one = ''
    if len(parking)>0: 
        for j in range(len(parking)):
            this_one = this_one + parking.iloc[j] + ' '        
    parking_data[i] = this_one

# %%
rest_profile.loc[:,'Parking'] = pd.Series(parking_data, index=rest_profile.index)

# %%
rest_profile.columns
# Out:
# Index(['placeID', 'latitude', 'longitude', 'the_geom_meter', 'name', 'address',
#        'city', 'state', 'country', 'fax', 'zip', 'alcohol', 'smoking_area',
#        'dress_code', 'accessibility', 'price', 'url', 'Rambience', 'franchise',
#        'area', 'other_services', 'Cuisine', 'Payment', 'Parking'],
#       dtype='object')

# %%
rest_profile
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# 5     135040  22.135617 -100.969709
# 6     132732  23.754357  -99.171288
# 7     132875  22.149901 -100.993779
# 8     132609  23.760268  -99.165865
# 9     135082  22.151448 -100.915099
# 10    135070  22.152918 -100.915164
# 11    135069  22.140129 -100.944872
# 12    135065  22.149580 -100.999557
# 13    135076  22.181017 -100.973614
# 14    135086  22.141421 -101.013955
# 15    132870  22.143078 -100.935479
# 16    132854  22.137863 -100.938327
# 17    132937  22.150019 -100.979920
# 18    132856  22.151378 -100.974634
# 19    132668  23.738212  -99.151955
# 20    135033  22.141610 -100.973142
# 21    132862  22.150643 -100.987015
# 22    134983  18.948657  -99.235361
# 23    132851  22.136872 -100.934574
# 24    135013  18.917441  -99.165945
# 25    135042  22.159357 -100.973411
# 26    132768  18.925773  -99.232636
# 27    132561  23.726819  -99.126506
# 28    135045  22.151189 -100.981790
# 29    132847  22.144336 -100.937382
# ..       ...        ...         ...
# 100   134996  18.923429  -99.216413
# 101   132755  22.153324 -101.019546
# 102   135043  22.185756 -100.944518
# 103   132654  23.735523  -99.129588
# 104   135049  22.135011 -101.028600
# 105   135073  22.147175 -100.974269
# 106   132560  23.752304  -99.166913
# 107   134976  18.916654  -99.227110
# 108   135075  22.139573 -100.991564
# 109   132660  23.752943  -99.164679
# 110   132921  22.150305 -100.989134
# 111   132594  23.752168  -99.165709
# 112   134986  18.928798  -99.239513
# 113   135062  22.153703 -100.979033
# 114   132766  18.910178  -99.231544
# 115   135088  18.876011  -99.219890
# 116   135058  22.165587 -101.001273
# 117   132754  22.147738 -100.990616
# 118   132584  23.752365  -99.165288
# 119   135032  22.152481 -100.973486
# 120   135028  22.146658 -100.987219
# 121   135085  22.150802 -100.982680
# 122   132663  23.752511  -99.166954
# 123   132626  23.737583  -99.135132
# 124   132583  18.922290  -99.234332
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# 5    0101000020957F00001B552189B84A58C15A2AAEFD2CA2...
# 6    0101000020957F00008A20E615808157C16272FECBF84F...
# 7    0101000020957F00008A2A0747DE4758C11EB31D2A31A8...
# 8    0101000020957F0000A478418BBA8057C133851EB22C4E...
# 9    0101000020957F0000A29FAF95CD4958C1FEEEBB73A991...
# 10   0101000020957F0000ED435B84934958C1B3CF85FA9791...
# 11   0101000020957F000038E5D546B74A58C18FD29AD0D29A...
# 12   0101000020957F000094A6A8E3C14758C17435E6D1DBA9...
# 13   0101000020957F00005657121FAA4358C1A8030D5598A0...
# 14   0101000020957F0000FA1A0E5A9B4858C17C884C4173AE...
# 15   0101000020957F0000550FC1FC854A58C16D7D4E35F897...
# 16   0101000020957F0000FEC3FB453E4B58C19B4A46361799...
# 17   0101000020957F0000F9F19DDC3B4858C191B265A83BA4...
# 18   0101000020957F0000C1B7D30B2C4858C1CE557111A5A2...
# 19   0101000020957F000003B195E25F8457C1C535BD04614B...
# 20   0101000020957F00000F624C60B54958C11757339BCCA2...
# 21   0101000020957F0000AF95272CF14758C165B2F91238A6...
# 22   0101000020957F0000DEF36F4FC76A5AC162B083D9A054...
# 23   0101000020957F0000C74DE39C7F4B58C1061F29171498...
# 24   0101000020957F0000D241E94E7B715AC119862B3B1E41...
# 25   0101000020957F0000C66BB014FC4658C17CFE8D93D2A1...
# 26   0101000020957F000000DD3546816E5AC119D4BD17FD54...
# 27   0101000020957F000004457BB7AA8657C15F10835CD944...
# 28   0101000020957F00000B6735CA004858C108FD525CB2A4...
# 29   0101000020957F00004717A23D474A58C17D1F10297098...
# ..                                                 ...
# 100  0101000020957F0000340233E7476F5AC132844E2A2C50...
# 101  0101000020957F000026CADE45A14658C1F011EBCA55AF...
# 102  0101000020957F00006B9D7207BE4358C12419118D0598...
# 103  0101000020957F000040E8F628488557C18224E8B94845...
# 104  0101000020957F00005DAD35642E4958C11BBCDE4A02B3...
# 105  0101000020957F0000D010A853D34858C116A1EA51CAA2...
# 106  0101000020957F0000FC60BDA8E88157C1B2C357D6DA4E...
# 107  0101000020957F00002838E29F19705AC1BC368BDAC753...
# 108  0101000020957F0000332AE8AF824958C15A4195A82CA8...
# 109  0101000020957F00003D7905C9DC8157C13FCD1AB7334E...
# 110  0101000020957F00006376BB64EF4758C1013687E5D7A6...
# 111  0101000020957F00003AE4C6DBF48157C1CE38ECC1864E...
# 112  0101000020957F00002A0D05E2D96D5AC1AB058CB1EC56...
# 113  0101000020957F0000D177B9CFB14758C162A211E1C2A3...
# 114  0101000020957F000043A319BA06715AC1944336987755...
# 115  0101000020957F0000E14AD4DBC7765AC1F7B33C85B153...
# 116  0101000020957F0000EB71019D424558C15CC5404365A9...
# 117  0101000020957F00002493B678494858C1AD55D2316BA7...
# 118  0101000020957F000048C65BA7EF8157C177F2344D664E...
# 119  0101000020957F000017D69FF5084858C1A8F2188740A2...
# 120  0101000020957F0000B4F00BDD8B4858C10AC3619C83A6...
# 121  0101000020957F00009F823DA6094858C18A2D4D37F9A4...
# 122  0101000020957F0000FDF8D26EE08157C1FEDB6A1FDB4E...
# 123  0101000020957F0000AA7883ADD88457C1FA651328BA46...
# 124  0101000020957F0000FBE7171F056F5AC1E8A6C0A5AF55...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# 127  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 128  0101000020957F0000B49B2E5C6E785AC12F9D58435241...
# 129  0101000020957F000090735015B84B58C1AF0DC0414698...
#
#                                                   name  \
# 0                                      Kiku Cuernavaca
# 1                                      puesto de tacos
# 2                           El Rincón de San Francisco
# 3                       little pizza Emilio Portes Gil
# 4                                        carnitas_mata
# 5                             Restaurant los Compadres
# 6                                   Taqueria EL amigo
# 7                                            shi ro ie
# 8                             Pollo_Frito_Buenos_Aires
# 9                                 la Estrella de Dimas
# 10                                      Restaurante 75
# 11                           Abondance Restaurante Bar
# 12                                El angel Restaurante
# 13                           Restaurante Pueblo Bonito
# 14                         Mcdonalds Parque Tangamanga
# 15                      Tortas y hamburguesas el gordo
# 16                                             Sirlone
# 17                                         rockabilly
# 18                                       Unicols Pizza
# 19                                      TACOS EL GUERO
# 20                    Restaurant El Muladar de Calzada
# 21                                La Posada del Virrey
# 22   Restaurant and Bar and Clothesline Carlos N Ch...
# 23                                                 KFC
# 24                                           Giovannis
# 25                         Restaurant Oriental Express
# 26                                  Mariscos Tia Licha
# 27                                          cafe ambar
# 28                             Restaurante la Gran Via
# 29                                        don burguers
# ..                                                 ...
# 100                               Sanborns Casa Piedra
# 101                               La Estrella de Dimas
# 102                                      pizza clasica
# 103              Carnitas Mata  Calle 16 de Septiembre
# 104                Restaurante de Mariscos la Langosta
# 105                       Restaurante Bar El Gallinero
# 106                                 puesto de gorditas
# 107                                            Log Yin
# 108                               Mariscos El Pescador
# 109              carnitas mata calle Emilio Portes Gil
# 110                                           crudalia
# 111                 tacos de barbacoa enfrente del Tec
# 112                           Restaurant Las Mananitas
# 113                      Restaurante El Cielo Potosino
# 114                                             Mikasa
# 115                                  Cafeteria cenidet
# 116                               Restaurante Tiberius
# 117                                    Cabana Huasteca
# 118                                 Gorditas Dona Tota
# 119                 Cafeteria y Restaurant El Pacifico
# 120                                        La Virreina
# 121                             Tortas Locas Hipocampo
# 122                                          tacos abi
# 123                              la perica hamburguesa
# 124                                   McDonalds Centro
# 125                                            Chaires
# 126                                         Sushi Itto
# 127                                          Paniroles
# 128                        Restaurant Bar Coty y Pablo
# 129                                   sirloin stockade
#
#                                              address             city  \
# 0                                         Revolucion       Cuernavaca
# 1             esquina santos degollado y leon guzman           s.l.p.
# 2                                    Universidad 169  San Luis Potosi
# 3                            calle emilio portes gil        victoria
# 4                             lic. Emilio portes gil         victoria
# 5                     Camino a Simon Diaz 155 Centro  San Luis Potosi
# 6                   Calle Mezquite Fracc Framboyanes      Cd Victoria
# 7                                                  ?                ?
# 8                                            tampico         victoria
# 9                  Villa de Pozos 192 Villa de Pozos  San Luis Potosi
# 10                Villa de Pozos 4497 Villa de Pozos  San Luis Potosi
# 11                       Industrias 908 Valle Dorado  San Luis Potosi
# 12                   Venustiano Carranza 1625 Jardin  San Luis Potosi
# 13                           Mexico 2015 Providencia  San Luis Potosi
# 14               Lateral Salvador Nava Martinez 3145  San Luis Potosi
# 15                                  Ricardo B. Anaya  San Luis Potosi
# 16                                      carr. mexico  San Luis Potosi
# 17                               agustin de iturbide  san luis potosi
# 18                                  Plaza del Carmen  San Luis Potosi
# 19                                                 ?         victoria
# 20                    De Guadalupe 460 San Miguelito  San Luis Potosi
# 21                                   Av. V. Carranza  San Luis Potosi
# 22                        Domingo 10 711 El Empleado       Cuernavaca
# 23                                                 ?  San Luis Potosi
# 24                       40 Norte Civac 1RA. Seccion         Jiutepec
# 25                           Tangamanga 7 Tangamanga  San Luis Potosi
# 26                         avenida salvador montiel        cuernavaca
# 27                                                 ?                ?
# 28                    Venustiano Carranza 560 Centro  San Luis Potosi
# 29                         r.b. anaya esq. florencia              slp
# ..                                               ...              ...
# 100                                Lomas del Mirador       Cuernavaca
# 101                              Av. de los Pintores  San Luis Potosi
# 102                  524 Soledad de Graciano Sanchez          Soledad
# 103                                 16 de Septiembre        victoria
# 104           Cordillera de Los Alpes 675 Loma Verde  San Luis Potosi
# 105                  Pascual M. Hernandez 210 Centro  San Luis Potosi
# 106                            frente al tecnologico         victoria
# 107                                                ?                ?
# 108                   Himno Nacional 2104 Tangamanga  San Luis Potosi
# 109                                Emilio Portes Gil         victoria
# 110                                                ?                ?
# 111                                                ?                ?
# 112                              Ricardo Linares 107       Cuernavaca
# 113                   Julian de Los Reyes 400 Centro  San Luis Potosi
# 114                 Himno nacional esq. Blvd. Juarez       Cuernavaca
# 115                    Interior Internado Palmira SN       Cuernavaca
# 116                                  Munoz Sn Centro  San Luis Potosi
# 117                                   Cuauhtemoc 455  San Luis Potosi
# 118                                                ?                ?
# 119                          Constitucion 200 Centro  San Luis Potosi
# 120                                 Av. Carranza 830  San Luis Potosi
# 121                   Venustiano Carranza 719 Centro  San Luis Potosi
# 122                                                ?         victoria
# 123                                                ?         victoria
# 124                             Rayon sn col. Centro       Cuernavaca
# 125                                 Ricardo B. Anaya  San Luis Potosi
# 126               Venustiano Carranza 1809 C Polanco  San Luis Potosi
# 127                                                ?                ?
# 128  Paseo de Las Fuentes 24 Pedregal de Las Fuentes         Jiutepec
# 129                                                ?                ?
#
#                state country fax       ...           accessibility   price  \
# 0            Morelos  Mexico   ?       ...        no_accessibility  medium
# 1             s.l.p.  mexico   ?       ...              completely     low
# 2    San Luis Potosi  Mexico   ?       ...               partially  medium
# 3         tamaulipas       ?   ?       ...              completely     low
# 4         Tamaulipas  Mexico   ?       ...              completely  medium
# 5                SLP  Mexico   ?       ...        no_accessibility    high
# 6         Tamaulipas  Mexico   ?       ...              completely     low
# 7                  ?       ?   ?       ...        no_accessibility    high
# 8         Tamaulipas  Mexico   ?       ...              completely     low
# 9                SLP  Mexico   ?       ...        no_accessibility  medium
# 10               SLP  Mexico   ?       ...        no_accessibility  medium
# 11               SLP  Mexico   ?       ...        no_accessibility     low
# 12               SLP  Mexico   ?       ...        no_accessibility    high
# 13               SLP  Mexico   ?       ...        no_accessibility    high
# 14               SLP  Mexico   ?       ...        no_accessibility  medium
# 15   San Luis Potosi  Mexico   ?       ...        no_accessibility     low
# 16   San Luis Potosi  Mexico   ?       ...              completely  medium
# 17   san luis potosi  mexico   ?       ...              completely     low
# 18   San Luis Potosi  Mexico   ?       ...              completely     low
# 19        tamaulipas  mexico   ?       ...              completely     low
# 20               SLP  Mexico   ?       ...        no_accessibility  medium
# 21   San Luis Potosi  Mexico   ?       ...              completely    high
# 22           Morelos  Mexico   ?       ...        no_accessibility    high
# 23   San Luis Potosi  Mexico   ?       ...              completely     low
# 24           Morelos  Mexico   ?       ...        no_accessibility     low
# 25               SLP  Mexico   ?       ...        no_accessibility  medium
# 26           morelos  mexico   ?       ...               partially  medium
# 27                 ?       ?   ?       ...              completely     low
# 28               SLP  Mexico   ?       ...        no_accessibility    high
# 29               slp  mexico   ?       ...        no_accessibility     low
# ..               ...     ...  ..       ...                     ...     ...
# 100          Morelos  Mexico   ?       ...        no_accessibility  medium
# 101           S.L.P.  Mexico   ?       ...               partially  medium
# 102              SLP  Mexico   ?       ...        no_accessibility  medium
# 103       tamaulipas       ?   ?       ...              completely     low
# 104              SLP  Mexico   ?       ...        no_accessibility  medium
# 105              SLP  Mexico   ?       ...        no_accessibility    high
# 106       tamaulipas  mexico   ?       ...        no_accessibility     low
# 107                ?       ?   ?       ...        no_accessibility     low
# 108              SLP  Mexico   ?       ...        no_accessibility  medium
# 109       tamaulipas       ?   ?       ...              completely     low
# 110                ?       ?   ?       ...              completely     low
# 111                ?       ?   ?       ...              completely     low
# 112          Morelos  Mexico   ?       ...        no_accessibility    high
# 113              SLP  Mexico   ?       ...        no_accessibility  medium
# 114          Morelos  Mexico   ?       ...        no_accessibility  medium
# 115          Morelos  Mexico   ?       ...        no_accessibility     low
# 116              SLP  Mexico   ?       ...        no_accessibility  medium
# 117           S.L.P.  Mexico   ?       ...               partially  medium
# 118                ?       ?   ?       ...              completely  medium
# 119              SLP  Mexico   ?       ...        no_accessibility  medium
# 120              SLP  Mexico   ?       ...        no_accessibility  medium
# 121              SLP  Mexico   ?       ...        no_accessibility  medium
# 122       tamaulipas  mexico   ?       ...              completely     low
# 123       tamaulipas       ?   ?       ...              completely  medium
# 124          Morelos  Mexico   ?       ...               partially     low
# 125  San Luis Potosi  Mexico   ?       ...              completely  medium
# 126              SLP  Mexico   ?       ...        no_accessibility  medium
# 127                ?       ?   ?       ...        no_accessibility  medium
# 128          Morelos  Mexico   ?       ...              completely     low
# 129                ?       ?   ?       ...              completely     low
#
#                        url Rambience franchise    area other_services  \
# 0    kikucuernavaca.com.mx  familiar         f  closed           none
# 1                        ?  familiar         f    open           none
# 2                        ?  familiar         f    open           none
# 3                        ?  familiar         t  closed           none
# 4                        ?  familiar         t  closed           none
# 5                        ?  familiar         f  closed           none
# 6                        ?  familiar         f    open           none
# 7                        ?  familiar         t    open       Internet
# 8                        ?     quiet         t  closed           none
# 9                        ?  familiar         f  closed           none
# 10                       ?  familiar         f  closed           none
# 11                       ?  familiar         f  closed           none
# 12                       ?  familiar         f  closed           none
# 13                       ?  familiar         f  closed           none
# 14                       ?  familiar         t  closed           none
# 15                       ?  familiar         f  closed           none
# 16                       ?  familiar         f  closed           none
# 17                       ?     quiet         f  closed        variety
# 18                       ?  familiar         f  closed           none
# 19                       ?  familiar         f  closed           none
# 20                       ?  familiar         f  closed           none
# 21                       ?  familiar         f  closed           none
# 22   carlosandcharlies.com  familiar         f  closed           none
# 23                       ?  familiar         f  closed           none
# 24                       ?  familiar         f  closed           none
# 25                       ?  familiar         f  closed           none
# 26                       ?  familiar         t  closed           none
# 27                       ?  familiar         f  closed           none
# 28        lagranvia.com.mx  familiar         f  closed           none
# 29                       ?  familiar         f    open           none
# ..                     ...       ...       ...     ...            ...
# 100                      ?  familiar         t  closed       Internet
# 101                      ?  familiar         f  closed        variety
# 102                      ?  familiar         f  closed           none
# 103                      ?  familiar         f  closed           none
# 104                      ?  familiar         f  closed           none
# 105                      ?  familiar         f  closed           none
# 106                      ?  familiar         f    open           none
# 107                      ?  familiar         f  closed           none
# 108                      ?  familiar         f  closed           none
# 109                      ?  familiar         f  closed           none
# 110                      ?     quiet         f    open           none
# 111                      ?  familiar         f    open           none
# 112    lasmananitas.com.mx  familiar         f  closed           none
# 113                      ?  familiar         f  closed           none
# 114                      ?  familiar         f  closed           none
# 115     www.cenidet.edu.mx     quiet         f  closed           none
# 116                      ?  familiar         t  closed           none
# 117                      ?  familiar         f  closed           none
# 118                      ?  familiar         t  closed           none
# 119                      ?  familiar         f  closed           none
# 120                      ?  familiar         f  closed           none
# 121                      ?  familiar         f  closed           none
# 122                      ?  familiar         f  closed           none
# 123                      ?  familiar         t  closed           none
# 124                     no  familiar         t  closed           none
# 125                      ?  familiar         f  closed           none
# 126      sushi-itto.com.mx  familiar         f  closed           none
# 127                      ?     quiet         f  closed       Internet
# 128                      ?  familiar         f  closed           none
# 129                      ?  familiar         f  closed           none
#
#                             Cuisine  \
# 0                         Japanese
# 1                          Mexican
# 2                          Mexican
# 3                         Armenian
# 4                          Mexican
# 5
# 6                          Mexican
# 7                         Japanese
# 8                        Fast_Food
# 9
# 10
# 11                             Bar
# 12
# 13
# 14               Burgers Fast_Food
# 15                         Burgers
# 16                   International
# 17                             Bar
# 18                         Italian
# 19                         Mexican
# 20
# 21                   International
# 22             Bar Bar_Pub_Brewery
# 23                   American Game
# 24
# 25                         Chinese
# 26                          Family
# 27
# 28
# 29
# ..                              ...
# 100
# 101                        Mexican
# 102             Fast_Food Pizzeria
# 103
# 104                        Seafood
# 105            Bar Bar_Pub_Brewery
# 106                       Regional
# 107  Mexican Mediterranean Burgers
# 108                        Seafood
# 109
# 110                            Bar
# 111                        Mexican
# 112                  International
# 113
# 114                       Japanese
# 115                      Cafeteria
# 116                       Pizzeria
# 117                        Mexican
# 118                        Mexican
# 119         Cafeteria Contemporary
# 120                        Mexican
# 121                      Fast_Food
# 122                        Mexican
# 123                        Italian
# 124                       American
# 125               Bakery Cafeteria
# 126                       Japanese
# 127                        Italian
# 128                            Bar
# 129
#
#                                                Payment         Parking
# 0                                                                none
# 1                                                cash            none
# 2                       cash VISA MasterCard-Eurocard            none
# 3                                                cash            none
# 4                                                cash             yes
# 5                       cash VISA MasterCard-Eurocard             yes
# 6                                                cash            none
# 7    cash VISA MasterCard-Eurocard American_Express...  valet parking
# 8                                                cash             yes
# 9                                                cash            none
# 10                                               cash             yes
# 11                                               cash             yes
# 12     cash VISA MasterCard-Eurocard American_Express            none
# 13     cash VISA MasterCard-Eurocard American_Express             yes
# 14                      cash VISA MasterCard-Eurocard             yes
# 15                                               cash            none
# 16                         cash VISA bank_debit_cards             yes
# 17                                               cash            none
# 18                                               cash            none
# 19                                                               none
# 20     cash VISA MasterCard-Eurocard American_Express            none
# 21   cash VISA MasterCard-Eurocard American_Express...  valet parking
# 22                      cash VISA MasterCard-Eurocard             yes
# 23                                               cash             yes
# 24                                               cash            none
# 25                                               cash            none
# 26                              cash bank_debit_cards            none
# 27                                                               none
# 28     cash VISA MasterCard-Eurocard American_Express             yes
# 29                                               cash            none
# ..                                                 ...             ...
# 100                                              cash             yes
# 101       cash VISA American_Express bank_debit_cards          public
# 102                                              cash            none
# 103                                                              none
# 104                                              cash            none
# 105                     cash VISA MasterCard-Eurocard             yes
# 106                                              cash          public
# 107  VISA MasterCard-Eurocard American_Express checks             yes
# 108                                              cash             yes
# 109                                                              none
# 110                                              cash            none
# 111                                              cash          public
# 112                                                               yes
# 113                                              cash             yes
# 114                                              cash             yes
# 115                                              cash          public
# 116                     cash VISA MasterCard-Eurocard          public
# 117                                              cash            none
# 118                                              cash             yes
# 119                     cash VISA MasterCard-Eurocard          public
# 120    cash VISA MasterCard-Eurocard American_Express            none
# 121                                              cash          public
# 122                                                              none
# 123                             cash American_Express             yes
# 124    cash VISA MasterCard-Eurocard bank_debit_cards            none
# 125                                              cash             yes
# 126    cash VISA MasterCard-Eurocard American_Express            none
# 127                                              cash            none
# 128                                                              none
# 129                                                              none
#
# [130 rows x 24 columns]

# %%
user_data = user_profile
users = np.array(user_data.userID)

# %%
cuisine_data = [0 for i in range(n_users)]

# %%
for i in range(len(cuisine_data)):
    cuisines = user_cuisine[user_cuisine['userID'] == users[i]]['Rcuisine']
    this_one = ''
    if len(cuisines)>0: 
        for j in range(len(cuisines)):
            this_one = this_one + cuisines.iloc[j] + ' '        
    cuisine_data[i] = this_one

# %%
user_data.loc[:,'Cuisine'] = pd.Series(cuisine_data, index=user_data.index)

# %%
payment_data = [0 for i in range(n_users)]

# %%
for i in range(len(payment_data)):
    payment = user_payment[user_payment['userID'] == users[i]]['Upayment']
    this_one = ''
    if len(payment)>0: 
        for j in range(len(payment)):
            this_one = this_one + payment.iloc[j] + ' '        
    payment_data[i] = this_one

# %%
user_data.loc[:,'Payment'] = pd.Series(payment_data, index=user_data.index)

# %%
user_data.columns
# Out:
# Index(['userID', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_preference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'interest', 'personality', 'religion', 'activity',
#        'color', 'weight', 'budget', 'height', 'Cuisine', 'Payment'],
#       dtype='object')

# %%
user_data
# Out:
#     userID   latitude   longitude smoker     drink_level dress_preference  \
# 0    U1001  22.139997 -100.978803  false      abstemious         informal
# 1    U1002  22.150087 -100.983325  false      abstemious         informal
# 2    U1003  22.119847 -100.946527  false  social drinker           formal
# 3    U1004  18.867000  -99.183000  false      abstemious         informal
# 4    U1005  22.183477 -100.959891  false      abstemious    no preference
# 5    U1006  22.150000 -100.983000   true  social drinker    no preference
# 6    U1007  22.118464 -100.938256  false  casual drinker         informal
# 7    U1008  22.122989 -100.923811  false  social drinker           formal
# 8    U1009  22.159427 -100.990448  false      abstemious           formal
# 9    U1010  22.190889 -100.998669  false  social drinker    no preference
# 10   U1011  23.724972  -99.152856  false      abstemious    no preference
# 11   U1012  18.813348  -99.243697  false  casual drinker           formal
# 12   U1013  22.174624 -100.993873  false      abstemious    no preference
# 13   U1014  23.751607  -99.170108  false      abstemious                ?
# 14   U1015  22.126760 -100.905209   true  social drinker         informal
# 15   U1016  22.156247 -100.977402  false  casual drinker         informal
# 16   U1017  18.952615  -99.201616  false  casual drinker           formal
# 17   U1018  22.190949 -100.917902   true  casual drinker           formal
# 18   U1019  22.153385 -100.975294  false  casual drinker    no preference
# 19   U1020  18.878189  -99.222969  false      abstemious    no preference
# 20   U1021  23.730569  -99.171883  false  social drinker    no preference
# 21   U1022  22.146708 -100.964355  false  casual drinker           formal
# 22   U1023  23.752943  -99.166589  false  casual drinker         informal
# 23   U1024  22.154021 -100.976028      ?      abstemious                ?
# 24   U1025  22.125603 -100.907844  false  social drinker    no preference
# 25   U1026  23.733000  -99.133000  false      abstemious           formal
# 26   U1027  22.165150 -100.987015   true  social drinker    no preference
# 27   U1028  23.752874  -99.169242  false      abstemious    no preference
# 28   U1029  22.151796 -100.989075   true  casual drinker           formal
# 29   U1030  18.844818  -99.182758  false  casual drinker           formal
# ..     ...        ...         ...    ...             ...              ...
# 108  U1109  22.303308 -101.054680  false      abstemious           formal
# 109  U1110  18.871678  -99.183263  false      abstemious    no preference
# 110  U1111  22.143078 -100.908523   true  casual drinker           formal
# 111  U1112  22.143078 -100.908523   true  casual drinker           formal
# 112  U1113  22.137343 -100.913935  false  casual drinker           formal
# 113  U1114  22.177726 -101.014094  false      abstemious    no preference
# 114  U1115  22.138127 -100.920512   true  social drinker          elegant
# 115  U1116  22.156469 -100.985540  false  social drinker           formal
# 116  U1117  18.875641  -99.220737  false      abstemious    no preference
# 117  U1118  18.940062  -99.228172   true  casual drinker         informal
# 118  U1119  18.964790  -99.260017  false      abstemious           formal
# 119  U1120  22.121857 -100.904279  false      abstemious         informal
# 120  U1121  18.871674  -99.183253  false  social drinker    no preference
# 121  U1122  22.169601 -100.991821      ?      abstemious                ?
# 122  U1123  23.753112  -99.168567  false      abstemious         informal
# 123  U1124  22.137072 -100.918865  false  casual drinker         informal
# 124  U1125  22.192040 -100.956935  false  casual drinker           formal
# 125  U1126  22.154210 -100.942233  false  casual drinker           formal
# 126  U1127  18.943935  -99.206532  false      abstemious    no preference
# 127  U1128  22.187236 -100.994213  false  casual drinker    no preference
# 128  U1129  23.728798  -99.134047  false  casual drinker    no preference
# 129  U1130  23.733000  -99.133000      ?      abstemious                ?
# 130  U1131  22.138245 -100.910948   true  social drinker    no preference
# 131  U1132  22.150000 -100.983000  false  casual drinker         informal
# 132  U1133  18.886698  -99.114979  false      abstemious    no preference
# 133  U1134  22.149654 -100.998610  false  casual drinker    no preference
# 134  U1135  22.170396 -100.949936  false  casual drinker         informal
# 135  U1136  22.149607 -100.997235   true  social drinker    no preference
# 136  U1137  22.144803 -100.944623  false  social drinker           formal
# 137  U1138  22.152884 -100.939663  false  social drinker           formal
#
#      ambience  transport marital_status        hijos  \
# 0      family    on foot         single  independent
# 1      family     public         single  independent
# 2      family     public         single  independent
# 3      family     public         single  independent
# 4      family     public         single  independent
# 5     friends  car owner         single  independent
# 6    solitary     public         single  independent
# 7    solitary     public         single  independent
# 8      family    on foot         single         kids
# 9     friends  car owner        married         kids
# 10     family     public         single  independent
# 11     family     public         single  independent
# 12    friends     public          widow  independent
# 13    friends     public         single  independent
# 14     family     public         single  independent
# 15    friends    on foot         single  independent
# 16     family     public         single            ?
# 17    friends     public         single  independent
# 18     family     public         single  independent
# 19    friends     public         single  independent
# 20     family  car owner         single    dependent
# 21     family  car owner         single  independent
# 22    friends  car owner         single  independent
# 23          ?          ?              ?            ?
# 24     family     public         single            ?
# 25     family     public         single  independent
# 26          ?     public         single  independent
# 27     family     public         single  independent
# 28     family     public         single  independent
# 29     family    on foot         single  independent
# ..        ...        ...            ...          ...
# 108  solitary     public         single  independent
# 109    family  car owner         single  independent
# 110   friends  car owner         single  independent
# 111   friends  car owner         single  independent
# 112    family     public         single  independent
# 113    family    on foot         single  independent
# 114   friends     public         single  independent
# 115    family     public        married         kids
# 116   friends     public         single  independent
# 117   friends     public         single  independent
# 118    family     public         single  independent
# 119   friends     public         single  independent
# 120    family     public        married  independent
# 121         ?          ?              ?            ?
# 122    family          ?         single  independent
# 123   friends     public         single  independent
# 124   friends     public         single  independent
# 125   friends    on foot         single  independent
# 126  solitary     public         single  independent
# 127   friends     public         single  independent
# 128   friends     public         single  independent
# 129         ?          ?              ?            ?
# 130   friends  car owner        married         kids
# 131  solitary     public         single            ?
# 132    family  car owner         single  independent
# 133    family     public         single  independent
# 134    family    on foot         single         kids
# 135   friends  car owner         single  independent
# 136    family     public         single  independent
# 137   friends     public         single  independent
#
#                 ...                   interest          personality  \
# 0               ...                    variety    thrifty-protector
# 1               ...                 technology  hunter-ostentatious
# 2               ...                       none          hard-worker
# 3               ...                    variety          hard-worker
# 4               ...                       none    thrifty-protector
# 5               ...                    variety          hard-worker
# 6               ...                    variety    thrifty-protector
# 7               ...                 technology          hard-worker
# 8               ...                    variety    thrifty-protector
# 9               ...                 technology          hard-worker
# 10              ...                    variety          hard-worker
# 11              ...                 technology          hard-worker
# 12              ...                      retro    thrifty-protector
# 13              ...                       none          hard-worker
# 14              ...                 technology    thrifty-protector
# 15              ...               eco-friendly    thrifty-protector
# 16              ...                      retro  hunter-ostentatious
# 17              ...                 technology    thrifty-protector
# 18              ...                    variety    thrifty-protector
# 19              ...                 technology          hard-worker
# 20              ...                       none          hard-worker
# 21              ...                    variety          hard-worker
# 22              ...                       none          hard-worker
# 23              ...                       none          hard-worker
# 24              ...                       none    thrifty-protector
# 25              ...                 technology  hunter-ostentatious
# 26              ...                      retro    thrifty-protector
# 27              ...                    variety          hard-worker
# 28              ...                    variety           conformist
# 29              ...               eco-friendly          hard-worker
# ..              ...                        ...                  ...
# 108             ...               eco-friendly    thrifty-protector
# 109             ...                    variety    thrifty-protector
# 110             ...                       none          hard-worker
# 111             ...                       none          hard-worker
# 112             ...                       none    thrifty-protector
# 113             ...                    variety          hard-worker
# 114             ...                    variety          hard-worker
# 115             ...                 technology    thrifty-protector
# 116             ...                 technology    thrifty-protector
# 117             ...                 technology    thrifty-protector
# 118             ...               eco-friendly    thrifty-protector
# 119             ...                    variety          hard-worker
# 120             ...                    variety    thrifty-protector
# 121             ...                       none          hard-worker
# 122             ...                 technology          hard-worker
# 123             ...                       none          hard-worker
# 124             ...                 technology          hard-worker
# 125             ...                 technology          hard-worker
# 126             ...                    variety          hard-worker
# 127             ...                    variety    thrifty-protector
# 128             ...                    variety    thrifty-protector
# 129             ...                       none          hard-worker
# 130             ...               eco-friendly          hard-worker
# 131             ...                       none          hard-worker
# 132             ...                       none          hard-worker
# 133             ...                    variety          hard-worker
# 134             ...                    variety  hunter-ostentatious
# 135             ...                      retro    thrifty-protector
# 136             ...               eco-friendly          hard-worker
# 137             ...                    variety    thrifty-protector
#
#       religion       activity   color weight  budget height  \
# 0         none        student   black     69  medium   1.77
# 1     Catholic        student     red     40     low   1.87
# 2     Catholic        student    blue     60     low   1.69
# 3         none   professional   green     44  medium   1.53
# 4     Catholic        student   black     65  medium   1.69
# 5         none        student    blue     75  medium   1.80
# 6     Catholic        student  purple     60     low   1.59
# 7     Catholic        student   green     68     low   1.72
# 8     Catholic        student   green     75  medium   1.78
# 9         none        student   green     40  medium   1.67
# 10    Catholic        student  purple     68  medium   1.78
# 11    Catholic        student     red     98  medium   1.84
# 12        none   professional    blue     80  medium   1.75
# 13    Catholic        student    blue     53  medium   1.69
# 14    Catholic        student   black     87  medium   1.67
# 15    Catholic        student   green     70  medium   1.67
# 16        none   professional  orange     79  medium   1.79
# 17   Christian        student    blue     65     low   1.83
# 18    Catholic        student  purple     59  medium   1.60
# 19    Catholic   professional    blue     40  medium   1.68
# 20    Catholic        student  purple    108  medium   1.62
# 21    Catholic        student  purple     46  medium   1.54
# 22    Catholic        student    blue    103     low   1.79
# 23        none              ?  yellow     40       ?   1.20
# 24    Catholic        student     red     65  medium   1.79
# 25    Catholic        student     red     49  medium   1.55
# 26    Catholic        student  purple     60     low   1.65
# 27   Christian        student    blue     77  medium   1.63
# 28    Catholic        student   white     58     low   1.60
# 29    Catholic        student   black     64  medium   1.75
# ..         ...            ...     ...    ...     ...    ...
# 108   Catholic        student    blue     57     low   1.72
# 109   Catholic        student     red     85  medium   1.75
# 110   Catholic        student   white     69  medium   1.69
# 111   Catholic        student   white     69  medium   1.69
# 112   Catholic        student    blue     75  medium   1.73
# 113   Catholic        student    blue     58  medium   1.68
# 114   Catholic        student   green     76     low   1.76
# 115   Catholic        student    blue     40  medium   1.71
# 116   Catholic   professional    blue     58  medium   1.60
# 117       none        student   black     60  medium   1.68
# 118   Catholic        student    blue     68  medium   1.68
# 119       none        student   green     47     low   1.57
# 120   Catholic  working-class   black     90  medium   1.60
# 121       none              ?  yellow     40       ?   1.20
# 122   Catholic        student   green    110  medium   1.75
# 123   Catholic        student    blue     51     low   1.20
# 124   Catholic        student   white     57     low   1.67
# 125   Catholic        student  purple     65     low   1.63
# 126   Catholic        student   black     65     low   1.76
# 127   Catholic        student     red     66     low   1.72
# 128       none        student  purple     69     low   1.69
# 129       none              ?  yellow     40       ?   1.20
# 130       none        student   black     90  medium   1.80
# 131       none        student    blue     55       ?   1.60
# 132       none        student  orange     60  medium   1.57
# 133   Catholic        student   black     52  medium   1.65
# 134   Catholic        student  purple     66     low   1.54
# 135   Catholic        student   black     50     low   1.60
# 136   Catholic        student    blue     72     low   1.78
# 137       none        student    blue     54  medium   1.55
#
#                                                Cuisine  \
# 0                                            American
# 1                                             Mexican
# 2                                             Mexican
# 3    Bakery Breakfast-Brunch Japanese Contemporary ...
# 4                                            American
# 5                                             Mexican
# 6                                              Family
# 7    Cafe-Coffee_Shop Mexican Juice Hawaiian Hot_Do...
# 8    Diner Fast_Food Family Cafe-Coffee_Shop Deli-S...
# 9                                             Mexican
# 10                                            Mexican
# 11                                     Latin_American
# 12                                           Japanese
# 13                                 Japanese Fast_Food
# 14                                            Mexican
# 15   Cafe-Coffee_Shop Contemporary Regional Fusion ...
# 16                                            Chinese
# 17                                            Mexican
# 18                                             Family
# 19                                            Mexican
# 20                  Pizzeria Regional Chinese Burgers
# 21                                            Mexican
# 22                                            Mexican
# 23                                             Afghan
# 24                                            Mexican
# 25                                            Mexican
# 26                                             Family
# 27                                            Mexican
# 28                                            Mexican
# 29                                            Mexican
# ..                                                 ...
# 108                                           Mexican
# 109                                           Mexican
# 110                                           Mexican
# 111                                           Mexican
# 112                                           Burgers
# 113                                           Mexican
# 114                                          Regional
# 115                                           Mexican
# 116                                           Turkish
# 117                                          Pizzeria
# 118                                           Mexican
# 119                                           Mexican
# 120                                           Mexican
# 121                                            Afghan
# 122                                           Mexican
# 123                                           Mexican
# 124                                           Mexican
# 125                                           Mexican
# 126                                           Mexican
# 127               Cafeteria Hot_Dogs Pizzeria Mexican
# 128                                           Mexican
# 129                                           Mexican
# 130                                           Mexican
# 131                                           Mexican
# 132                                           Mexican
# 133                                           Mexican
# 134  Organic-Healthy Steaks Middle_Eastern Mediterr...
# 135                                           Mexican
# 136                                           Mexican
# 137                                          Pizzeria
#
#                          Payment
# 0                          cash
# 1                          cash
# 2                          cash
# 3         cash bank_debit_cards
# 4                          cash
# 5                          cash
# 6                          cash
# 7                          cash
# 8                          cash
# 9                          cash
# 10                         cash
# 11        cash bank_debit_cards
# 12     MasterCard-Eurocard cash
# 13                         cash
# 14                         cash
# 15                         cash
# 16                    cash VISA
# 17                         cash
# 18                         cash
# 19        cash bank_debit_cards
# 20                         cash
# 21                         cash
# 22                         cash
# 23
# 24
# 25        cash bank_debit_cards
# 26                         cash
# 27                         cash
# 28                         cash
# 29                         cash
# ..                           ...
# 108                        cash
# 109                        cash
# 110                        cash
# 111                        cash
# 112                   VISA cash
# 113                        cash
# 114                        cash
# 115  cash bank_debit_cards VISA
# 116       bank_debit_cards cash
# 117                        cash
# 118                        cash
# 119                        cash
# 120       cash bank_debit_cards
# 121
# 122                        cash
# 123                        cash
# 124                        cash
# 125                        cash
# 126                        cash
# 127                        cash
# 128                        cash
# 129
# 130                        cash
# 131                        cash
# 132       bank_debit_cards cash
# 133                        cash
# 134                        cash
# 135                        cash
# 136                        cash
# 137                        cash
#
# [138 rows x 21 columns]

# %%
def get_context(user, rest, user_profile, rest_profile):
    this_user = user_profile[user_profile['userID']==user]
    this_rest = rest_profile[rest_profile['placeID'] == rest]
    
    #print (this_user)
    #print (this_rest)
    contexts = 0
    
    if this_user['smoker'].item() == 'true' and (this_rest['smoking_area'].item() == 'section'or this_rest['smoking_area'].item() == 'permitted' or this_rest['smoking_area'].item() == 'only at bar'):
        contexts = contexts + 1
    
    if (this_user['drink_level'].item() == 'casual drinker' or this_user['drink_level'].item() == 'social_drinker') and this_rest['alcohol'].item() == 'Wine-Beer' or this_rest['alcohol'].item() == 'Full_Bar':
        contexts = contexts + 1 
    
    if (this_user['dress_preference'].item() == 'formal' or this_user['dress_preference'].item() == 'elegant') and (this_rest['dress_code'].item() == 'formal' or this_rest['Rambience'].item() == 'quiet' or this_rest['franchise'].item()== 'f'):
        contexts = contexts + 1 
        
    if (this_user['dress_preference'].item() == 'informal') and (this_rest['dress_code'].item() == 'informal' or this_rest['dress_code'].item() == 'casual'):
        contexts = contexts + 1 
    
    if (this_user['ambience'].item() == 'family' or this_user['ambience'].item() == 'friends') and (this_rest['Rambience'].item() == 'familiar'):
        contexts = contexts + 1 
    
    if (this_user['ambience'].item() == 'solitary') and (this_rest['Rambience'].item() == 'quiet'):
        contexts = contexts + 1
    
    if (this_user['transport'].item() == 'car owner') and (this_rest['Parking'].item() == 'yes' or this_rest['Parking'].item() == 'public' or this_rest['Parking'].item() == 'valet parking'):
        contexts = contexts + 1 
        
    if (this_user['activity'].item() == 'student' or this_user['activity'].item() == 'working class') and (this_rest['price'].item() == 'low' or this_rest['price'].item() == 'medium'):
        contexts = contexts + 1 
    
    if (this_user['activity'].item() == 'unemployed') and (this_rest['price'].item() == 'low'):
        contexts = contexts + 1 
    
    if (this_user['activity'].item() == 'professional') and (this_rest['price'].item() == 'medium' or this_rest['price'].item() == 'high'):
        contexts = contexts + 1 
    
    if (this_user['budget'].item() == 'high') and (this_rest['price'].item() == 'high'):
        contexts = contexts + 1 
    
    if (this_user['budget'].item() == 'medium') and (this_rest['price'].item() == 'medium'):
        contexts = contexts + 1 
    
    if (this_user['budget'].item() == 'low') and (this_rest['price'].item() == 'low' or this_rest['franchise'].item() == 't'):
        contexts + contexts + 1 
        
    this_user_cuisines = this_user['Cuisine'].item().split(' ')
    this_rest_cuisines = this_rest['Cuisine'].item()
    
    this_user_payment = this_user['Payment'].item().split(' ')
    this_rest_payment = this_rest['Payment'].item()
    
    for j in range(len(this_user_cuisines)-1):
        if this_user_cuisines[j] in this_rest_cuisines:
            contexts = contexts + 1
    
    for m in range(len(this_user_payment)-1):
        if this_user_payment[m] in this_rest_payment:
            contexts = contexts + 1 
        
    return contexts

# %%
from scipy.sparse import rand as sprand
from scipy.sparse import lil_matrix

# %%
n_users = len(user_data.userID.unique())
n_items = len(rest_profile.placeID.unique())
print (n_users)
print (n_items)
# Out:
# 138
# 130

# %%
user_list = np.array(user_data.userID.unique())
item_list = np.array(rest_profile.placeID.unique())

# %%
contexts_full = lil_matrix((n_users, n_items), dtype = float)
for i in range(len(user_list)):
    for j in range(len(item_list)):
        contexts_full[i, j] = get_context(user_list[i], item_list[j], user_data, rest_profile)

# %%
contexts_norm = lil_matrix((n_users, n_items), dtype = float)
for i in range(len(user_list)):
    for j in range(len(item_list)):
        contexts_norm[i, j] = (get_context(user_list[i], item_list[j], user_data, rest_profile))/11.0

# %% [markdown]
# ## Standardizing the user profile

# %%
user_profile = pd.read_csv(user_profile_dir)

# %%
users = np.array(user_profile.userID)
cuisine_types = np.array(user_cuisine.Rcuisine.unique())

# %%
len(cuisine_types)
# Out:
# 103

# %%
cuisine_data = [[0 for i in range(len(cuisine_types)) ] for j in range(len(users))]

# %%
for i in range(len(cuisine_data)):
    cuisines = user_cuisine[user_cuisine['userID'] == users[i]]['Rcuisine']
    if len(cuisines) > 0:
        for j in range(len(cuisines)):
            this_cuisine = cuisines.iloc[j]
            here, = np.where(cuisine_types == this_cuisine)
            cuisine_data[i][here[0]] = 1

# %%
#create a pandas dataframe with the cuisines
cuisinedf = pd.DataFrame(data = cuisine_data, columns = cuisine_types)

# %%
user_profile = pd.concat([user_profile, cuisinedf], axis=1)

# %%
payment_types = np.array(user_payment.Upayment.unique())
len(payment_types)
# Out:
# 5

# %%
payment_data = [[0 for i in range(len(payment_types))] for j in range(len(users))]

# %%
for i in range(len(payment_data)):
    payment = user_payment[user_payment['userID'] == users[i]]['Upayment']
    if len(payment)>0:
        for j in range(len(payment)):
            this_payment = payment.iloc[j]
            here, = np.where(payment_types == this_payment)
            payment_data[i][here[0]] = 1

# %%
paymentdf = pd.DataFrame(data = payment_data, columns = payment_types)

# %%
user_profile = pd.concat([user_profile, paymentdf], axis =1)

# %%
len(user_profile.columns)
# Out:
# 152

# %%
user_columns = user_profile.columns[:30]
print (user_columns)
# Out:
# Index(['userID', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_preference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'interest', 'personality', 'religion', 'activity',
#        'color', 'weight', 'budget', 'height', 'American', 'Mexican', 'Bakery',
#        'Breakfast-Brunch', 'Japanese', 'Contemporary', 'Bagels',
#        'Cafe-Coffee_Shop', 'Continental-European', 'Cafeteria', 'Family'],
#       dtype='object')

# %%
#replace smoking
user_profile['smoker'] = user_profile['smoker'].replace(['false', '?'], 0)
user_profile['smoker'] = user_profile['smoker'].replace(['true'], 1)

# %%
#replace hijos 
user_profile['hijos'] = user_profile['hijos'].replace(['independent', '?'], 0)
user_profile['hijos'] = user_profile['hijos'].replace(['kids', 'dependent'], 1)

# %%
#replace married
user_profile['marital_status'] = user_profile['marital_status'].replace(['single', '?', 'widow'], 0)
user_profile['marital_status'] = user_profile['marital_status'].replace(['married'], 1)

# %%
#drop latitude, longitude, weight, height, color
#encode age?

# %%
user_profile= pd.get_dummies(user_profile, columns=["drink_level", "dress_preference","ambience", "transport", "interest", "personality", 
                                     "religion", "activity", "budget"])

# %%
user_profile = user_profile.drop(['latitude', 'longitude', 'weight', 'height', 'color'], axis = 1)

# %% [markdown]
# ## Calculating Similarity Matrices Among Users - Euclidean and Pearson

# %%
user_matrix = user_profile.drop(['userID'], axis = 1)

# %%
user_matrix_val = user_matrix.values

# %%
euclidean_mat = [[0 for i in range(len(users)) ] for j in range(len(users))]

# %%
#find the euclidean distance between users
for i in range(len(users)):
    for j in range(len(users)):
        if i==j:
            euclidean_mat[i][j] = 0
        else:
            a = user_matrix_val[i]
            b = user_matrix_val[j]
            euclidean_mat[i][j] = -1*np.linalg.norm(a-b)

# %%
#sort and get the indicies of top? 
sorted_euclidean = np.argsort(euclidean_mat, axis=1)

# %%
neighbors = 15

# %%
top_e = sorted_euclidean[:,:neighbors]
top_e
# Out:
# array([[105, 121,  23, ..., 134,  50,  82],
#        [ 23, 121, 105, ...,  50, 134,  82],
#        [121, 105,  23, ...,  50, 134,  82],
#        ...,
#        [121,  23, 105, ...,  50, 134,  82],
#        [ 23, 121, 105, ...,  50, 134,  82],
#        [121,  23, 105, ...,  50, 134,  82]])

# %%
import scipy.stats

# %%
pearson_mat = [[0 for i in range(len(users)) ] for j in range(len(users))]

# %%
for i in range(len(users)):
    for j in range(len(users)):
        if i==j:
            pearson_mat[i][j] = 0
        else:
            a = user_matrix_val[i]
            b = user_matrix_val[j]
            pearson_mat[i][j] = -1*scipy.stats.pearsonr(a,b)[0]

# %%
sorted_pearson = np.argsort(pearson_mat, axis=1)

# %%
top_p = sorted_pearson[:,:neighbors]
top_p
# Out:
# array([[109,   4,  46, ...,  86,  49,  27],
#        [ 25,  65,  80, ..., 118,  53,  93],
#        [136,  97,  35, ...,  31,  55,  87],
#        ...,
#        [ 26,  79,  37, ...,  22,  24, 130],
#        [  2,  95,  53, ..., 108,  31,  62],
#        [117,  39,  53, ..., 118,  69,  99]])

# %% [markdown]
# ## Get the Ratings + the new Ratings based on the weighted average of "close" people

# %%
ratings = pd.read_csv(rating_dir)

# %%
from sklearn.model_selection import train_test_split
rating_train, rating_test = train_test_split(ratings, test_size=0.3)

# %%
interactions_full_orig = lil_matrix((n_users, n_items), dtype = float)
interactions_full_SIM_P = lil_matrix((n_users, n_items), dtype = float)
interactions_full_SIM_E = lil_matrix((n_users, n_items), dtype = float)
for row in ratings.itertuples():
    user, = np.where(user_list == row[1])
    item, = np.where(item_list == row[2])
    interactions_full_orig[user[0], item[0]] = row[3] 
    interactions_full_SIM_P[user[0], item[0]] = row[3]
    interactions_full_SIM_E[user[0], item[0]] = row[3]

# %%
interactions_train_orig = lil_matrix((n_users, n_items), dtype = float)
interactions_train_SIM_E = lil_matrix((n_users, n_items), dtype = float)
interactions_train_SIM_P = lil_matrix((n_users, n_items), dtype = float)
for row in rating_train.itertuples():
    user, = np.where(user_list == row[1])
    item, = np.where(item_list == row[2])
    interactions_train_orig[user[0], item[0]] = row[3]
    interactions_train_SIM_E[user[0], item[0]] = row[3]
    interactions_train_SIM_P[user[0], item[0]] = row[3]

# %%
interactions_test_orig = lil_matrix((n_users, n_items), dtype = float)
interactions_test_SIM_E = lil_matrix((n_users, n_items), dtype = float)
interactions_test_SIM_P = lil_matrix((n_users, n_items), dtype = float)
for row in rating_test.itertuples():
    user, = np.where(user_list == row[1])
    item, = np.where(item_list == row[2])
    interactions_test_orig[user[0], item[0]] = row[3]
    interactions_test_SIM_E[user[0], item[0]] = row[3]
    interactions_test_SIM_P[user[0], item[0]] = row[3]

# %%
rat_train_dense = interactions_train_orig.todense()
rat_test_dense = interactions_test_orig.todense()
rat_full_dense = interactions_full_orig.todense()

# %%
for i in range(interactions_train_orig.shape[0]):
    top = top_e[i]
    
    for m in range(n_items):
        if m not in interactions_train_orig[0].rows[0]:
            other = interactions_train_orig[j]
            total = 0.0
            count = 0.0
            for j in range(neighbors):
                if m in interactions_train_orig[top[j]].rows[0]:
                    total = total + (rat_train_dense[top[j],m])* -1* (euclidean_mat[top[j]][m])
                    count = count + (-1* (euclidean_mat[top[j]][m]))
        
            if count == 0:
                nm = 0
            else:
                nm = total/count
            
            interactions_train_SIM_E[i,m] = nm

# %%
for i in range(interactions_test_orig.shape[0]):
    top = top_e[i]
    
    for m in range(n_items):
        if m not in interactions_test_orig[0].rows[0]:
            other = interactions_test_orig[j]
            total = 0.0
            count = 0.0
            for j in range(neighbors):
                if m in interactions_test_orig[top[j]].rows[0]:
                    total = total + (rat_test_dense[top[j],m])* -1* (euclidean_mat[top[j]][m])
                    count = count + 1 * -1* (euclidean_mat[top[j]][m])
        
            if count == 0:
                nm = 0
            else:
                nm = total/count
            
            interactions_test_SIM_E[i,m] = nm

# %%
for i in range(interactions_train_orig.shape[0]):
    top = top_p[i]
    
    for m in range(n_items):
        if m not in interactions_train_orig[0].rows[0]:
            other = interactions_train_orig[j]
            total = 0.0
            count = 0.0
            for j in range(neighbors):
                if m in interactions_train_orig[top[j]].rows[0]:
                    total = total + (rat_train_dense[top[j],m])* -1* (pearson_mat[top[j]][m])
                    count = count + 1*( -1* (pearson_mat[top[j]][m]))
        
            if count == 0:
                nm = 0
            else:
                nm = total/count
            
            interactions_train_SIM_P[i,m] = nm

# %%
for i in range(interactions_test_orig.shape[0]):
    top = top_p[i]
    
    for m in range(n_items):
        if m not in interactions_test_orig[0].rows[0]:
            other = interactions_test_orig[j]
            total = 0.0
            count = 0.0
            for j in range(neighbors):
                if m in interactions_test_orig[top[j]].rows[0]:
                    total = total + (rat_test_dense[top[j],m])* -1* (pearson_mat[top[j]][m])
                    count = count + 1*( -1* (pearson_mat[top[j]][m]))
        
            if count == 0:
                nm = 0
            else:
                nm = total/count
            
            interactions_test_SIM_P[i,m] = nm

# %%
for i in range(interactions_full_orig.shape[0]):
    top = top_p[i]
    
    for m in range(n_items):
        if m not in interactions_full_orig[0].rows[0]:
            other = interactions_full_orig[j]
            total = 0.0
            count = 0.0
            for j in range(neighbors):
                if m in interactions_full_orig[top[j]].rows[0]:
                    total = total + (rat_full_dense[top[j],m])* -1* (pearson_mat[top[j]][m])
                    count = count + 1*( -1* (pearson_mat[top[j]][m]))
        
            if count == 0:
                nm = 0
            else:
                nm = total/count
            
            interactions_full_SIM_P[i,m] = nm

# %%
for i in range(interactions_full_orig.shape[0]):
    top = top_p[i]
    
    for m in range(n_items):
        if m not in interactions_full_orig[0].rows[0]:
            other = interactions_full_orig[j]
            total = 0.0
            count = 0.0
            for j in range(neighbors):
                if m in interactions_full_orig[top[j]].rows[0]:
                    total = total + (rat_full_dense[top[j],m])* -1* (euclidean_mat[top[j]][m])
                    count = count + 1*( -1* (euclidean_mat[top[j]][m]))
        
            if count == 0:
                nm = 0
            else:
                nm = total/count
            
            interactions_full_SIM_E[i,m] = nm

# %% [markdown]
# ## Begin the Model

# %%
class MatrixFactorization(torch.nn.Module):
    
    def __init__(self, n_users, n_items, n_factors=5):
        super().__init__()
        self.user_factors = torch.nn.Embedding(n_users,
                                               n_factors,
                                               sparse=False)
        self.item_factors = torch.nn.Embedding(n_items,n_factors,sparse=False)
                  
    
    def forward(self, users, items, context):
        #return (self.user_factors(user) * self.item_factors(item)).sum(1)
    
        orig = torch.mm(self.user_factors(users),torch.transpose(self.item_factors(items),0,1))
        
        #here = torch.from_numpy(context)
        #context = torch.mm(self.user_context(users), torch.transpose(self.item_context(items),0,1))
        
        #fused_context = context * self.fusion.expand_as(context)
        
        mat = torch.add(orig, context)
        return mat
        #return torch.mm(self.user_factors(users),torch.transpose(self.item_factors(items),0,1))

# %%
class BiasedMatrixFactorization(torch.nn.Module):
    
    def __init__(self, n_users, n_items,mean, n_factors=5):
        super().__init__()
        self.user_factors = torch.nn.Embedding(n_users,
                                               n_factors,
                                               sparse=False)
        self.item_factors = torch.nn.Embedding(n_items, n_factors,sparse=False)
        self.user_biases = torch.nn.Embedding(n_users, 1, sparse = False)
        
        self.item_biases = torch.nn.Embedding(n_items,1, sparse = False)
                                               
        self.mu = mean
    
    
    def forward(self, users, items, context):
        
        item_means = []
        user_means = []
        for i in range(len(users)):
            item_means.append(torch.t(self.item_biases(items)))
            
        for j in range(len(items)):
            user_means.append(torch.t(self.user_biases(users)))
        
        it_means = torch.cat(item_means, 0)
        us_means = torch.cat(user_means, 0)
        us_means = torch.t(us_means)
        
        orig = torch.mm(self.user_factors(users),torch.transpose(self.item_factors(items),0,1))
        
        y = torch.add(orig, it_means)
        
        f = torch.add(y,us_means)
        
        result = torch.add(f,self.mu)
        
        mat = torch.add(result, context)
        
        return mat

# %%
def get_batch(batch_size,ratings):
    # Sort our data and scramble it
    rows, cols = ratings.shape
    p = np.random.permutation(rows)
    
    # create batches
    sindex = 0
    eindex = batch_size
    while eindex < rows:
        batch = p[sindex:eindex]
        temp = eindex
        eindex = eindex + batch_size
        sindex = temp
        yield batch

    if eindex >= rows:
        batch = range(sindex,rows)
        yield batch

# %%
def load_model(model,load_path):
    load_dict = torch.load(load_path)
    val_loss = load_dict['val_loss']
    model.load_state_dict(load_dict['model_state_dict'])


def checkpoint_model(val_loss, model,save_path):
    save_dict = dict(
                     val_loss=val_loss,
                     model_state_dict=model.state_dict())
                     #opt_state_dict=predictions.state_dict())
    torch.save(save_dict, save_path)

# %%
def run_validation(model, test_ratings_SIM, test_ratings, BATCH_SIZE, load_path):
    load_model(model, load_path)
    running_loss = 0.0
    loss_func = torch.nn.MSELoss()
    accur = 0
    for i,batch in enumerate(get_batch(BATCH_SIZE, test_ratings_SIM)):
        
        interactions = Variable(torch.FloatTensor(test_ratings_SIM[batch, :].toarray()))
        rows = Variable(torch.LongTensor(batch))
        cols = Variable(torch.LongTensor(np.arange(test_ratings_SIM.shape[1])))
        
        predictions = model(rows, cols)
        loss = loss_func(predictions, interactions)
        
        running_loss += np.sqrt(loss.data[0])*BATCH_SIZE
        
        correct = get_accuracy(test_ratings_SIM,test_ratings, model, rows)
        accur = accur+ correct
    
    epoch_loss = running_loss/test_ratings_SIM.shape[0]
    return epoch_loss,accur

# %%
def run_validation_context(model, test_ratings_SIM, test_ratings, context_mat, fusion, BATCH_SIZE, load_path):
    load_model(model, load_path)
    running_loss = 0.0
    loss_func = torch.nn.MSELoss()
    accur = 0
    for i,batch in enumerate(get_batch(BATCH_SIZE, test_ratings_SIM)):
        
        interactions = Variable(torch.FloatTensor(test_ratings_SIM[batch, :].toarray()))
        rows = Variable(torch.LongTensor(batch))
        cols = Variable(torch.LongTensor(np.arange(test_ratings_SIM.shape[1])))
        
        first = (context_mat[batch,:].toarray())*fusion
        contexts = Variable(torch.FloatTensor(first))
        
        
        predictions = model(rows, cols, contexts)
        loss = loss_func(predictions, interactions)
        
        running_loss += np.sqrt(loss.data[0])*BATCH_SIZE
        
        correct = get_accuracy_context(test_ratings_SIM,test_ratings, model, rows, fusion, context_mat)
        accur = accur+ correct
    
    epoch_loss = running_loss/test_ratings_SIM.shape[0]
    return epoch_loss,accur

# %%
def get_accuracy(interactions_SIM, interactions_orig,model,rows):
    
    checks = np.nonzero(interactions_orig)
    check_these = checks[0]
    
    batch = range(interactions_SIM.shape[0])
    interactions = Variable(torch.FloatTensor(interactions_SIM[batch,:].toarray()))
    users = Variable(torch.LongTensor(batch))
    cols = Variable(torch.LongTensor(np.arange(interactions_SIM.shape[1])))
    predictions = model(users, cols)
    
    x = predictions.data.numpy()
    
    correct = 0
    
    for u in range(len(rows)):
        user = rows.data[u]
        where = np.where(check_these==user)
        index = where[0]
        if len(index) > 0:
            for c in range(len(index)):
                rest = checks[1][index[c]]
                prediction = predictions[u][rest]
                   
                val = prediction.data[0]
                
                if val <= np.percentile(x,22):
                    this_val = 0.0
                elif np.percentile(x,22) < val < np.percentile(x, 58):
                    this_val = 1.0
                elif val >= np.percentile(x, 58):
                     this_val= 2.0
        
                
                if this_val == interactions_orig[user,rest]:
                    correct = correct + 1 
            else:
                next
    return correct

# %%
def get_accuracy_context(interactions_SIM, interactions_orig,model,rows,fusion, contexts_full):
    
    checks = np.nonzero(interactions_orig)
    check_these = checks[0]
    
    batch = range(interactions_SIM.shape[0])
    interactions = Variable(torch.FloatTensor(interactions_SIM[batch,:].toarray()))
    users = Variable(torch.LongTensor(batch))
    cols = Variable(torch.LongTensor(np.arange(interactions_SIM.shape[1])))
    
    first = (contexts_full[batch,:].toarray())*fusion
    contexts = Variable(torch.FloatTensor(first))
    
    predictions = model(users, cols, contexts)
    
    x = predictions.data.numpy()
    
    correct = 0
    
    for u in range(len(rows)):
        user = rows.data[u]
        where = np.where(check_these==user)
        index = where[0]
        if len(index) > 0:
            for c in range(len(index)):
                rest = checks[1][index[c]]
                prediction = predictions[u][rest]
                   
                val = prediction.data[0]
                
                if val <= np.percentile(x,22):
                    this_val = 0.0
                elif np.percentile(x,22) < val < np.percentile(x, 58):
                    this_val = 1.0
                elif val >= np.percentile(x, 58):
                     this_val= 2.0
        
                
                if this_val == interactions_orig[user,rest]:
                    correct = correct + 1 
            else:
                next
    return correct

# %%
def generate_predictions(model, contexts_full, interactions_sim, interactions_full, fusion, load_path):
    load_model(model, load_path)

    batch = range(interactions_sim.shape[0])
    interactions = Variable(torch.FloatTensor(interactions_sim[batch,:].toarray()))
    rows = Variable(torch.LongTensor(batch))
    cols = Variable(torch.LongTensor(np.arange(interactions_sim.shape[1])))
    first = (contexts_full[batch,:].toarray())*fusion
        
    #contexts = Variable(torch.FloatTensor(contexts_full[batch,:].toarray()))
    contexts = Variable(torch.FloatTensor(first))
        
    predictions = model(rows, cols, contexts)
    
    interactions2 = Variable(torch.FloatTensor(interactions_full[batch,:].toarray()))
    
    predictions[interactions2!=0] = 0
        
    val, index = torch.sort(predictions,1, descending = True)
        
    top5 = index[:,:5]
        
    return top5

# %%
def give_top5_cuisines(recs, name_list, cuisine_list, user_list, rest_list):
    your_rests = [[0 for j in range(11)] for u in range(len(user_list))]
    for i in range(len(user_list)):
        user, = np.where(user_list == user_list[i])
        your_rests[i][0] = user_list[i]
        count = 1
        for r in range(5):
            this_rest = recs[user[0]][r].data[0]
            rest = rest_list[this_rest]
            x = name_list.loc[name_list['placeID'] == rest]
            name = x['name'].item()
            
            your_rests[i][count] = name
            count = count +1
            
            y = cuisine_list.loc[cuisine_list['placeID'] == rest]['Rcuisine']
            
            cuisine_types = ''
            for m in y:
                cuisine_types = cuisine_types + m + ', '
            
            your_rests[i][count] = cuisine_types
            count = count + 1
            
    return your_rests

# %%
def give_number_of_contexts(recs, context, this_user,user_list, rest_list):
   
    contexts = [0 for i in range(5)]
    
    user, = np.where(this_user == user_list)
    print (user)
    
    for u in range(5):
        this_rest = recs[user[0]][u].data[0]
        contexts[u] = context[user[0], this_rest]
    
    return contexts

# %%
batch_size = 10
save_path = './project_models/model.ckpt'
save_path_val = './project_models/modelv.ckpt'
factors = [2,3,4,5]
fusion_arr = [0.0,1.0]

# %%
checks = np.nonzero(interactions_train_orig)
checks_v = np.nonzero(interactions_test_orig)

# %%
#Euclidean Distance
best_val_loss = 1000.0
best_val_accuracy = 0.0
#FOCUS ON FACTOR 2
for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(1):  
        fusion = 1.0
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = MatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1], n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_SIM_E)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_SIM_E[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_SIM_E.shape[1])))
                first = (contexts_full[batch,:].toarray())*fusion
        
                contexts = Variable(torch.FloatTensor(first))
                #predictions = model(rows, cols)
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_context(interactions_train_SIM_E, interactions_train_orig, model, rows, fusion, contexts_full)
            #correct = get_accuracy(interactions_train_SIM_E, interactions_train_orig, model, rows)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_SIM_E.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path)
        
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path)
            val_loss, val_accuracy = run_validation_context(model, interactions_test_SIM_E, interactions_test_orig, contexts_full, fusion,batch_size, save_path)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy)+ ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 1.0
# Epoch: 0
# train_loss: 3.8151748981124483
# accuracy:0.43285939968404424
# checkpoint model with train loss: 3.8151748981124483
# val loss: 3.930516918778681
# val accuracy: 0.4306569343065693
# checkpointing_model with val loss: 3.930516918778681
# New Best Val Accuracy: 0.4306569343065693 with fusion: 1.0 and factor :2
# Epoch: 1
# train_loss: 3.7943076296584204
# accuracy:0.41232227488151657
# checkpoint model with train loss: 3.7943076296584204
# val loss: 3.939097655510871
# val accuracy: 0.3759124087591241
# Epoch: 2
# train_loss: 3.823497646222488
# accuracy:0.4470774091627172
# val loss: 3.9348100172761478
# val accuracy: 0.4233576642335766
# Epoch: 3
# train_loss: 3.80264606693316
# accuracy:0.4060031595576619
# val loss: 3.97464476063009
# val accuracy: 0.40145985401459855
# Epoch: 4
# train_loss: 3.8345290558052905
# accuracy:0.4423380726698262
# val loss: 3.9327578391290103
# val accuracy: 0.40145985401459855

# %%
#Euclidean Distance
#context_norm
best_val_loss = 1000.0
best_val_accuracy = 0.0
#FOCUS ON FACTOR 2
for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(len(fusion_arr)):  
        fusion = 0
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = MatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1], n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_SIM_E)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_SIM_E[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_SIM_E.shape[1])))
                first = (contexts_norm[batch,:].toarray())*fusion
                #print (first)
        
                contexts = Variable(torch.FloatTensor(first))
                #predictions = model(rows, cols)
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_context(interactions_train_SIM_E, interactions_train_orig, model, rows, fusion, contexts_norm)
            #correct = get_accuracy(interactions_train_SIM_E, interactions_train_orig, model, rows)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_SIM_E.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path)
        
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path)
            val_loss, val_accuracy = run_validation_context(model, interactions_test_SIM_E, interactions_test_orig, contexts_norm, fusion,batch_size, save_path)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy)+ ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 0
# Epoch: 0
# train_loss: 1.4751177309534327
# accuracy:0.4195583596214511
# checkpoint model with train loss: 1.4751177309534327
# val loss: 1.4956723884934258
# val accuracy: 0.43223443223443225
# checkpointing_model with val loss: 1.4956723884934258
# New Best Val Accuracy: 0.43223443223443225 with fusion: 0 and factor :2
# Epoch: 1
# train_loss: 1.4881473243211203
# accuracy:0.3832807570977918
# val loss: 1.5161030360947874
# val accuracy: 0.43956043956043955
# New Best Val Accuracy: 0.43956043956043955 with fusion: 0 and factor :2
# Epoch: 2
# train_loss: 1.530080225960882
# accuracy:0.40536277602523657
# val loss: 1.5000531755389261
# val accuracy: 0.3882783882783883
# Epoch: 3
# train_loss: 1.517843250059643
# accuracy:0.3943217665615142
# val loss: 1.50407163933605
# val accuracy: 0.39194139194139194
# Epoch: 4
# train_loss: 1.5300708909035556
# accuracy:0.37381703470031546
# val loss: 1.492402444988429
# val accuracy: 0.3882783882783883
# checkpointing_model with val loss: 1.492402444988429
# FUSION: 0
# Epoch: 0
# train_loss: 1.3491832639613281
# accuracy:0.38958990536277605
# checkpoint model with train loss: 1.3491832639613281
# val loss: 1.342261505634464
# val accuracy: 0.36996336996337
# checkpointing_model with val loss: 1.342261505634464
# Epoch: 1
# train_loss: 1.3381627942209045
# accuracy:0.3911671924290221
# checkpoint model with train loss: 1.3381627942209045
# val loss: 1.3424877899710963
# val accuracy: 0.4065934065934066
# Epoch: 2
# train_loss: 1.3505677215927214
# accuracy:0.4116719242902208
# val loss: 1.2923762886427654
# val accuracy: 0.3992673992673993
# checkpointing_model with val loss: 1.2923762886427654
# Epoch: 3
# train_loss: 1.3242766743482988
# accuracy:0.3675078864353312
# checkpoint model with train loss: 1.3242766743482988
# val loss: 1.337263183700105
# val accuracy: 0.42124542124542125
# Epoch: 4
# train_loss: 1.3585273102478086
# accuracy:0.4148264984227129
# val loss: 1.3408378014789164
# val accuracy: 0.40293040293040294

# %%
col_names = ['User','Rec1', 'Rec1_Cuisines', 'Rec2', 'Rec2_Cuisines', 'Rec3', 
             'Rec3_Cuisines', 'Rec4','Rec4_Cuisines',  'Rec5', 'Rec5_Cuisines']

# %%
#Pearson Coefficient
best_val_loss = 1000.0
best_val_accuracy = 0.0
#FOCUS ON FACTOR 2
for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(1):  
        #fusion = fusion_arr[f]
        fusion = 1.0
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = BiasedMatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1], mean, n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_SIM_P)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_SIM_P[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_SIM_P.shape[1])))
                first = (contexts_full[batch,:].toarray())*fusion
        
                contexts = Variable(torch.FloatTensor(first))
                #predictions = model(rows, cols)
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_context(interactions_train_SIM_P, interactions_train_orig, model, rows, fusion, contexts_full)
            #correct = get_accuracy(interactions_train_SIM_E, interactions_train_orig, model, rows)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_SIM_P.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path)
        
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path)
            val_loss, val_accuracy = run_validation_context(model, interactions_test_SIM_P, interactions_test_orig, contexts_full, fusion,batch_size, save_path)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy)+ ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 1.0
# Epoch: 0
# train_loss: 3.820659435960233
# accuracy:0.47791798107255523
# checkpoint model with train loss: 3.820659435960233
# val loss: 4.023977354701263
# val accuracy: 0.5201465201465202
# checkpointing_model with val loss: 4.023977354701263
# New Best Val Accuracy: 0.5201465201465202 with fusion: 1.0 and factor :2
# Epoch: 1
# train_loss: 3.862341302218013
# accuracy:0.4605678233438486
# val loss: 4.02268299870417
# val accuracy: 0.45787545787545786
# checkpointing_model with val loss: 4.02268299870417
# Epoch: 2
# train_loss: 3.8717096118867453
# accuracy:0.4605678233438486
# val loss: 4.088140383082364
# val accuracy: 0.46153846153846156
# Epoch: 3
# train_loss: 3.865314164747259
# accuracy:0.501577287066246
# val loss: 4.064666958739246
# val accuracy: 0.4468864468864469
# Epoch: 4
# train_loss: 3.8583422771996094
# accuracy:0.4794952681388013
# val loss: 4.092608682109769
# val accuracy: 0.4542124542124542

# %%
recs = generate_predictions(model, contexts_full, interactions_full_orig, interactions_full_SIM_E, fusion, save_path_val)
results = give_top5_cuisines(recs, rest_profile, rest_cuisine, user_list, item_list)

# %%
give_number_of_contexts(recs, contexts_full, 'U1093', user_list,item_list)
# Out:
# [92]
# [6.0, 6.0, 2.0, 6.0, 5.0]

# %%
give_number_of_contexts(recs, contexts_full, 'U1077', user_list,item_list)
# Out:
# [76]
# [7.0, 5.0, 7.0, 6.0, 5.0]

# %%
df = pd.DataFrame(results,columns = col_names)

# %%
len(df['Rec5'].value_counts().index.tolist())
# Out:
# 46

# %%
df[df['User']== 'U1093'].values
# Out:
# array([['U1093', 'Restaurant El Muladar de Calzada', '', 'Vips', '',
#         'Restaurante y Pescaderia Tampico', 'Seafood, ',
#         'El Rincón de San Francisco', 'Mexican, ', 'vips', 'Mexican, ']],
#       dtype=object)

# %%
df[df['User']== 'U1077'].values
# Out:
# array([['U1077', 'vips', 'Mexican, ', 'cafe punta del cielo',
#         'Cafeteria, ', 'El Rincón de San Francisco', 'Mexican, ',
#         'Restaurant El Muladar de Calzada', '',
#         'Restaurante de Mariscos la Langosta', 'Seafood, ']], dtype=object)

# %%
#Pearson 
#context_norm
best_val_loss = 1000.0
best_val_accuracy = 0.0

for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(len(fusion_arr)):  
        fusion = fusion_arr[f]
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = MatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1], n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_SIM_P)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_SIM_P[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_SIM_P.shape[1])))
                first = (contexts_norm[batch,:].toarray())*fusion
        
                contexts = Variable(torch.FloatTensor(first))
                #predictions = model(rows, cols)
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_context(interactions_train_SIM_P, interactions_train_orig, model, rows, fusion, contexts_norm)
            #correct = get_accuracy(interactions_train_SIM_E, interactions_train_orig, model, rows)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_SIM_P.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path)
        
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path)
            val_loss, val_accuracy = run_validation_context(model, interactions_test_SIM_P, interactions_test_orig, contexts_norm, fusion,batch_size, save_path)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy)+ ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 0.0
# Epoch: 0
# train_loss: 1.9097777606599595
# accuracy:0.37066246056782337
# checkpoint model with train loss: 1.9097777606599595
# val loss: 1.7664581341810683
# val accuracy: 0.3663003663003663
# checkpointing_model with val loss: 1.7664581341810683
# New Best Val Accuracy: 0.3663003663003663 with fusion: 0.0 and factor :2
# Epoch: 1
# train_loss: 1.8995913041085437
# accuracy:0.4085173501577287
# checkpoint model with train loss: 1.8995913041085437
# val loss: 1.755335653178724
# val accuracy: 0.4358974358974359
# checkpointing_model with val loss: 1.755335653178724
# New Best Val Accuracy: 0.4358974358974359 with fusion: 0.0 and factor :2
# Epoch: 2
# train_loss: 1.9076858343906742
# accuracy:0.3943217665615142
# val loss: 1.7383997527298298
# val accuracy: 0.42124542124542125
# checkpointing_model with val loss: 1.7383997527298298
# Epoch: 3
# train_loss: 1.9083596851535243
# accuracy:0.42586750788643535
# val loss: 1.757681261423319
# val accuracy: 0.41025641025641024
# Epoch: 4
# train_loss: 1.8669805415957454
# accuracy:0.4037854889589905
# checkpoint model with train loss: 1.8669805415957454
# val loss: 1.752250977581526
# val accuracy: 0.4175824175824176
# FUSION: 1.0
# Epoch: 0
# train_loss: 1.6398032924943426
# accuracy:0.4069400630914827
# checkpoint model with train loss: 1.6398032924943426
# val loss: 1.5291658585309946
# val accuracy: 0.4249084249084249
# checkpointing_model with val loss: 1.5291658585309946
# Epoch: 1
# train_loss: 1.6404903410564866
# accuracy:0.361198738170347
# val loss: 1.5600338670747056
# val accuracy: 0.3956043956043956
# Epoch: 2
# train_loss: 1.6360140105332535
# accuracy:0.3722397476340694
# checkpoint model with train loss: 1.6360140105332535
# val loss: 1.5241488460065797
# val accuracy: 0.38095238095238093
# checkpointing_model with val loss: 1.5241488460065797
# Epoch: 3
# train_loss: 1.6430184326323463
# accuracy:0.35331230283911674
# val loss: 1.5365238466927515
# val accuracy: 0.43223443223443225
# Epoch: 4
# train_loss: 1.6559884522124988
# accuracy:0.38170347003154576
# val loss: 1.5334215723941198
# val accuracy: 0.3626373626373626

# %%
mean = np.mean(interactions_train_orig)
save_path_b = './project_models/bmodel.ckpt'
save_path_val_b = './project_models/bmodelv.ckpt'

# %%
#Euclidean Distance
best_val_loss = 1000.0
best_val_accuracy = 0.0
#FOCUS ON FACTOR 2
for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(len(fusion_arr)):  
        fusion = 1.0
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = BiasedMatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1],mean, n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_SIM_E)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_SIM_E[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_SIM_E.shape[1])))
                first = (contexts_full[batch,:].toarray())*fusion
        
                contexts = Variable(torch.FloatTensor(first))
                #predictions = model(rows, cols)
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_context(interactions_train_SIM_E, interactions_train_orig, model, rows, fusion, contexts_full)
            #correct = get_accuracy(interactions_train_SIM_E, interactions_train_orig, model, rows)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_SIM_E.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path_b)
        
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path)
            val_loss, val_accuracy = run_validation_context(model, interactions_test_SIM_E, interactions_test_orig, contexts_full, fusion,batch_size, save_path_b)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val_b)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val_b)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy)+ ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 1.0
# Epoch: 0
# train_loss: 3.937960452319388
# accuracy:0.43759873617693523
# checkpoint model with train loss: 3.937960452319388
# val loss: 4.104613756372536
# val accuracy: 0.4306569343065693
# checkpointing_model with val loss: 4.104613756372536
# New Best Val Accuracy: 0.4306569343065693 with fusion: 1.0 and factor :2
# Epoch: 1
# train_loss: 3.9685611770404816
# accuracy:0.4312796208530806
# val loss: 4.050210139011982
# val accuracy: 0.4489051094890511
# checkpointing_model with val loss: 4.050210139011982
# New Best Val Accuracy: 0.4489051094890511 with fusion: 1.0 and factor :2
# Epoch: 2
# train_loss: 3.8947109154080612
# accuracy:0.40916271721958924
# checkpoint model with train loss: 3.8947109154080612
# val loss: 4.11121239502249
# val accuracy: 0.4927007299270073
# New Best Val Accuracy: 0.4927007299270073 with fusion: 1.0 and factor :2
# Epoch: 3
# train_loss: 3.982972099040826
# accuracy:0.4028436018957346
# val loss: 4.073445658255646
# val accuracy: 0.48905109489051096
# Epoch: 4
# train_loss: 3.945401367705126
# accuracy:0.4486571879936809
# val loss: 4.100074053155132
# val accuracy: 0.4416058394160584
# FUSION: 1.0
# Epoch: 0
# train_loss: 3.9825810548886076
# accuracy:0.4391785150078989
# checkpoint model with train loss: 3.9825810548886076
# val loss: 4.1275991910194785
# val accuracy: 0.4744525547445255
# Epoch: 1
# train_loss: 3.984613593151235
# accuracy:0.4391785150078989
# val loss: 4.071554869793773
# val accuracy: 0.4489051094890511
# Epoch: 2
# train_loss: 3.9422750316465422
# accuracy:0.43601895734597157
# checkpoint model with train loss: 3.9422750316465422
# val loss: 4.095973686004328
# val accuracy: 0.41605839416058393
# Epoch: 3
# train_loss: 3.967515680057967
# accuracy:0.4518167456556082
# val loss: 4.084459022632518
# val accuracy: 0.4744525547445255
# Epoch: 4
# train_loss: 3.95940825824475
# accuracy:0.45023696682464454
# val loss: 4.064259820224612
# val accuracy: 0.4562043795620438

# %%
recs = generate_predictions(model, contexts_full, interactions_full_orig, interactions_full_SIM_E, fusion, save_path_val_b)
results = give_top5_cuisines(recs, rest_profile, rest_cuisine, user_list, item_list)

# %%
#Pearson Coefficient
best_val_loss = 1000.0
best_val_accuracy = 0.0

for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(len(fusion_arr)):  
        fusion = fusion_arr[f]
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = BiasedMatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1],mean, n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_SIM_P)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_SIM_P[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_SIM_P.shape[1])))
                first = (contexts_full[batch,:].toarray())*fusion
        
                contexts = Variable(torch.FloatTensor(first))
                #predictions = model(rows, cols)
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_context(interactions_train_SIM_P, interactions_train_orig, model, rows, fusion, contexts_full)
            #correct = get_accuracy(interactions_train_SIM_E, interactions_train_orig, model, rows)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_SIM_P.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path_b)
        
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path)
            val_loss, val_accuracy = run_validation_context(model, interactions_test_SIM_P, interactions_test_orig, contexts_full, fusion,batch_size, save_path_b)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val_b)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val_b)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy)+ ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 0.0
# Epoch: 0
# train_loss: 2.002863560526983
# accuracy:0.46845425867507884
# checkpoint model with train loss: 2.002863560526983
# val loss: 1.9439555707660658
# val accuracy: 0.5091575091575091
# checkpointing_model with val loss: 1.9439555707660658
# New Best Val Accuracy: 0.5091575091575091 with fusion: 0.0 and factor :2
# Epoch: 1
# train_loss: 1.9924860288800985
# accuracy:0.44637223974763407
# checkpoint model with train loss: 1.9924860288800985
# val loss: 1.9273554510875326
# val accuracy: 0.4945054945054945
# checkpointing_model with val loss: 1.9273554510875326
# Epoch: 2
# train_loss: 2.006573524603645
# accuracy:0.4794952681388013
# val loss: 1.9424919387049477
# val accuracy: 0.4468864468864469
# Epoch: 3
# train_loss: 2.004109039709521
# accuracy:0.49369085173501576
# val loss: 1.936815102128787
# val accuracy: 0.4652014652014652
# Epoch: 4
# train_loss: 1.9804826683995744
# accuracy:0.4668769716088328
# checkpoint model with train loss: 1.9804826683995744
# val loss: 1.9088662272715131
# val accuracy: 0.4835164835164835
# checkpointing_model with val loss: 1.9088662272715131
# FUSION: 1.0
# Epoch: 0
# train_loss: 4.37166159112284
# accuracy:0.37697160883280756
# checkpoint model with train loss: 4.37166159112284
# val loss: 4.450994183277596
# val accuracy: 0.3772893772893773
# Epoch: 1
# train_loss: 4.4102291461725125
# accuracy:0.3548895899053628
# val loss: 4.4640907953446
# val accuracy: 0.3663003663003663
# Epoch: 2
# train_loss: 4.403951126025858
# accuracy:0.3832807570977918
# val loss: 4.451225616321078
# val accuracy: 0.3553113553113553
# Epoch: 3
# train_loss: 4.425620005349495
# accuracy:0.3801261829652997
# val loss: 4.472092288845314
# val accuracy: 0.3076923076923077
# Epoch: 4
# train_loss: 4.417990429906927
# accuracy:0.3864353312302839
# val loss: 4.484305468402185
# val accuracy: 0.3772893772893773

# %%
#Euclidean Distance
#context norm
best_val_loss = 1000.0
best_val_accuracy = 0.0
#FOCUS ON FACTOR 2
for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(len(fusion_arr)):  
        fusion = fusion_arr[f]
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = BiasedMatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1],mean, n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_SIM_E)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_SIM_E[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_SIM_E.shape[1])))
                first = (contexts_norm[batch,:].toarray())*fusion
        
                contexts = Variable(torch.FloatTensor(first))
                #predictions = model(rows, cols)
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_context(interactions_train_SIM_E, interactions_train_orig, model, rows, fusion, contexts_norm)
            #correct = get_accuracy(interactions_train_SIM_E, interactions_train_orig, model, rows)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_SIM_E.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path_b)
        
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path)
            val_loss, val_accuracy = run_validation_context(model, interactions_test_SIM_E, interactions_test_orig, contexts_norm, fusion,batch_size, save_path_b)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val_b)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val_b)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy)+ ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 0.0
# Epoch: 0
# train_loss: 2.4029043794643496
# accuracy:0.44637223974763407
# checkpoint model with train loss: 2.4029043794643496
# val loss: 2.3402342688550526
# val accuracy: 0.3956043956043956
# checkpointing_model with val loss: 2.3402342688550526
# New Best Val Accuracy: 0.3956043956043956 with fusion: 0.0 and factor :2
# Epoch: 1
# train_loss: 2.397502189143252
# accuracy:0.4227129337539432
# checkpoint model with train loss: 2.397502189143252
# val loss: 2.3444545780547386
# val accuracy: 0.3553113553113553
# Epoch: 2
# train_loss: 2.3906152354635397
# accuracy:0.40063091482649843
# checkpoint model with train loss: 2.3906152354635397
# val loss: 2.324585135799029
# val accuracy: 0.4139194139194139
# checkpointing_model with val loss: 2.324585135799029
# New Best Val Accuracy: 0.4139194139194139 with fusion: 0.0 and factor :2
# Epoch: 3
# train_loss: 2.398682487261816
# accuracy:0.4195583596214511
# val loss: 2.3423919226331797
# val accuracy: 0.43223443223443225
# New Best Val Accuracy: 0.43223443223443225 with fusion: 0.0 and factor :2
# Epoch: 4
# train_loss: 2.395532366376844
# accuracy:0.42902208201892744
# val loss: 2.3480808438331233
# val accuracy: 0.3663003663003663
# FUSION: 1.0
# Epoch: 0
# train_loss: 2.2683607973036444
# accuracy:0.3659305993690852
# checkpoint model with train loss: 2.2683607973036444
# val loss: 2.2774722505318032
# val accuracy: 0.37362637362637363
# checkpointing_model with val loss: 2.2774722505318032
# Epoch: 1
# train_loss: 2.2697978786717474
# accuracy:0.3359621451104101
# val loss: 2.268668447450238
# val accuracy: 0.3443223443223443
# checkpointing_model with val loss: 2.268668447450238
# Epoch: 2
# train_loss: 2.2510339562172588
# accuracy:0.37066246056782337
# checkpoint model with train loss: 2.2510339562172588
# val loss: 2.2906369995094793
# val accuracy: 0.304029304029304
# Epoch: 3
# train_loss: 2.2500674078615863
# accuracy:0.3359621451104101
# checkpoint model with train loss: 2.2500674078615863
# val loss: 2.2654633830392785
# val accuracy: 0.3443223443223443
# checkpointing_model with val loss: 2.2654633830392785
# Epoch: 4
# train_loss: 2.2252013068724703
# accuracy:0.39747634069400634
# checkpoint model with train loss: 2.2252013068724703
# val loss: 2.2815066830914676
# val accuracy: 0.336996336996337

# %%
#Pearson Coefficient
#context norm
best_val_loss = 1000.0
best_val_accuracy = 0.0

for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(len(fusion_arr)):  
        fusion = fusion_arr[f]
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = BiasedMatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1],mean, n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_SIM_P)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_SIM_P[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_SIM_P.shape[1])))
                first = (contexts_norm[batch,:].toarray())*fusion
        
                contexts = Variable(torch.FloatTensor(first))
                #predictions = model(rows, cols)
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_context(interactions_train_SIM_P, interactions_train_orig, model, rows, fusion, contexts_norm)
            #correct = get_accuracy(interactions_train_SIM_E, interactions_train_orig, model, rows)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_SIM_P.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path_b)
        
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path)
            val_loss, val_accuracy = run_validation_context(model, interactions_test_SIM_P, interactions_test_orig, contexts_norm, fusion,batch_size, save_path_b)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val_b)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val_b)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy)+ ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 0.0
# Epoch: 0
# train_loss: 2.081429011434301
# accuracy:0.32018927444794953
# checkpoint model with train loss: 2.081429011434301
# val loss: 2.0440156789468977
# val accuracy: 0.32234432234432236
# checkpointing_model with val loss: 2.0440156789468977
# New Best Val Accuracy: 0.32234432234432236 with fusion: 0.0 and factor :2
# Epoch: 1
# train_loss: 2.1095082961199005
# accuracy:0.3501577287066246
# val loss: 2.031054048921989
# val accuracy: 0.2600732600732601
# checkpointing_model with val loss: 2.031054048921989
# Epoch: 2
# train_loss: 2.0833406844326126
# accuracy:0.3264984227129338
# val loss: 2.062031146787092
# val accuracy: 0.3333333333333333
# New Best Val Accuracy: 0.3333333333333333 with fusion: 0.0 and factor :2
# Epoch: 3
# train_loss: 2.101612329808129
# accuracy:0.33753943217665616
# val loss: 2.0423580262184355
# val accuracy: 0.3516483516483517
# New Best Val Accuracy: 0.3516483516483517 with fusion: 0.0 and factor :2
# Epoch: 4
# train_loss: 2.096481106798703
# accuracy:0.3643533123028391
# val loss: 2.0777849150362213
# val accuracy: 0.32234432234432236
# FUSION: 1.0
# Epoch: 0
# train_loss: 2.0719719921093365
# accuracy:0.4605678233438486
# checkpoint model with train loss: 2.0719719921093365
# val loss: 2.065006876464174
# val accuracy: 0.4432234432234432
# New Best Val Accuracy: 0.4432234432234432 with fusion: 1.0 and factor :2
# Epoch: 1
# train_loss: 2.083314822098583
# accuracy:0.43217665615141954
# val loss: 2.073748394495787
# val accuracy: 0.48717948717948717
# New Best Val Accuracy: 0.48717948717948717 with fusion: 1.0 and factor :2
# Epoch: 2
# train_loss: 2.0365585614181048
# accuracy:0.4589905362776025
# checkpoint model with train loss: 2.0365585614181048
# val loss: 2.0660591180678853
# val accuracy: 0.4652014652014652
# Epoch: 3
# train_loss: 2.07809005993361
# accuracy:0.4195583596214511
# val loss: 2.066640875964384
# val accuracy: 0.42857142857142855
# Epoch: 4
# train_loss: 2.078355369052865
# accuracy:0.44952681388012616
# val loss: 2.0807270025966758
# val accuracy: 0.43223443223443225
