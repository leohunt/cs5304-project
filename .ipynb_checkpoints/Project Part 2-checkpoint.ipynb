# %%
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
import torchvision
import math
from torch.autograd import Variable
import copy
import torchvision.transforms as transforms

# %%
import pandas as pd 
import numpy as np

# %%
#not using bours of restaurants, since we have no information on what time people are looking to eat

# %%
rating_dir = './RCdata/rating_final.csv'
rest_profile_dir = './RCdata/geoplaces2.csv'
rest_cuisine_dir = './RCdata/chefmozcuisine.csv'
rest_payment_dir = './RCdata/chefmozaccepts.csv'
rest_parking_dir = './RCdata/chefmozparking.csv'
user_cuisine_dir = './RCdata/usercuisine.csv'
user_payment_dir = './RCdata/userpayment.csv'
user_profile_dir = './RCdata/userprofile.csv'

# %%
rest_profile = pd.read_csv(rest_profile_dir, encoding = 'cp1252')
rest_cuisine = pd.read_csv(rest_cuisine_dir) #encoding = 'cp1252')
rest_payment = pd.read_csv(rest_payment_dir)
rest_parking = pd.read_csv(rest_parking_dir)

# %%
rest_parking.columns
# Out:
# Index(['placeID', 'parking_lot'], dtype='object')

# %%
n_rests = len(rest_profile.placeID)
print (n_rests)
# Out:
# 130

# %%
rests = np.array(rest_profile.placeID)

# %%
cuisine_data = [0 for i in range(n_rests)]

# %%
for i in range(len(cuisine_data)):
    cuisines = rest_cuisine[rest_cuisine['placeID'] == rests[i]]['Rcuisine']
    this_one = ''
    if len(cuisines)>0: 
        for j in range(len(cuisines)):
            this_one = this_one + cuisines.iloc[j] + ' '        
    cuisine_data[i] = this_one

# %%
rest_profile.loc[:,'Cuisine'] = pd.Series(cuisine_data, index=rest_profile.index)

# %%
payment_data = [0 for i in range(n_rests)]

# %%
for i in range(len(payment_data)):
    payment = rest_payment[rest_payment['placeID'] == rests[i]]['Rpayment']
    this_one = ''
    if len(payment)>0: 
        for j in range(len(payment)):
            this_one = this_one + payment.iloc[j] + ' '        
    payment_data[i] = this_one

# %%
rest_profile.loc[:,'Payment'] = pd.Series(payment_data, index=rest_profile.index)

# %%
parking_data = [0 for i in range(n_rests)]

# %%
for i in range(len(parking_data)):
    parking = rest_parking[rest_parking['placeID'] == rests[i]]['parking_lot']
    this_one = ''
    if len(parking)>0: 
        for j in range(len(parking)):
            this_one = this_one + parking.iloc[j] + ' '        
    parking_data[i] = this_one

# %%
rest_profile.loc[:,'Parking'] = pd.Series(parking_data, index=rest_profile.index)

# %%
rest_profile.shape
# Out:
# (130, 24)

# %%
rest_profile.columns
# Out:
# Index(['placeID', 'latitude', 'longitude', 'the_geom_meter', 'name', 'address',
#        'city', 'state', 'country', 'fax', 'zip', 'alcohol', 'smoking_area',
#        'dress_code', 'accessibility', 'price', 'url', 'Rambience', 'franchise',
#        'area', 'other_services', 'Cuisine', 'Payment', 'Parking'],
#       dtype='object')

# %%
user_profile = pd.read_csv(user_profile_dir)
user_payment = pd.read_csv(user_payment_dir)
user_cuisine = pd.read_csv(user_cuisine_dir)

# %%
user_cuisine.columns
# Out:
# Index(['userID', 'Rcuisine'], dtype='object')

# %%
n_users = len(user_profile.userID)
print (n_users)
# Out:
# 138

# %%
users = np.array(user_profile.userID)

# %%
cuisine_data = [0 for i in range(n_users)]

# %%
for i in range(len(cuisine_data)):
    cuisines = user_cuisine[user_cuisine['userID'] == users[i]]['Rcuisine']
    this_one = ''
    if len(cuisines)>0: 
        for j in range(len(cuisines)):
            this_one = this_one + cuisines.iloc[j] + ' '        
    cuisine_data[i] = this_one

# %%
user_profile.loc[:,'Cuisine'] = pd.Series(cuisine_data, index=user_profile.index)

# %%
payment_data = [0 for i in range(n_users)]

# %%
for i in range(len(payment_data)):
    payment = user_payment[user_payment['userID'] == users[i]]['Upayment']
    this_one = ''
    if len(payment)>0: 
        for j in range(len(payment)):
            this_one = this_one + payment.iloc[j] + ' '        
    payment_data[i] = this_one

# %%
user_profile.loc[:,'Payment'] = pd.Series(payment_data, index=user_profile.index)

# %%
user_profile
# Out:
#     userID   latitude   longitude smoker     drink_level dress_preference  \
# 0    U1001  22.139997 -100.978803  false      abstemious         informal
# 1    U1002  22.150087 -100.983325  false      abstemious         informal
# 2    U1003  22.119847 -100.946527  false  social drinker           formal
# 3    U1004  18.867000  -99.183000  false      abstemious         informal
# 4    U1005  22.183477 -100.959891  false      abstemious    no preference
# 5    U1006  22.150000 -100.983000   true  social drinker    no preference
# 6    U1007  22.118464 -100.938256  false  casual drinker         informal
# 7    U1008  22.122989 -100.923811  false  social drinker           formal
# 8    U1009  22.159427 -100.990448  false      abstemious           formal
# 9    U1010  22.190889 -100.998669  false  social drinker    no preference
# 10   U1011  23.724972  -99.152856  false      abstemious    no preference
# 11   U1012  18.813348  -99.243697  false  casual drinker           formal
# 12   U1013  22.174624 -100.993873  false      abstemious    no preference
# 13   U1014  23.751607  -99.170108  false      abstemious                ?
# 14   U1015  22.126760 -100.905209   true  social drinker         informal
# 15   U1016  22.156247 -100.977402  false  casual drinker         informal
# 16   U1017  18.952615  -99.201616  false  casual drinker           formal
# 17   U1018  22.190949 -100.917902   true  casual drinker           formal
# 18   U1019  22.153385 -100.975294  false  casual drinker    no preference
# 19   U1020  18.878189  -99.222969  false      abstemious    no preference
# 20   U1021  23.730569  -99.171883  false  social drinker    no preference
# 21   U1022  22.146708 -100.964355  false  casual drinker           formal
# 22   U1023  23.752943  -99.166589  false  casual drinker         informal
# 23   U1024  22.154021 -100.976028      ?      abstemious                ?
# 24   U1025  22.125603 -100.907844  false  social drinker    no preference
# 25   U1026  23.733000  -99.133000  false      abstemious           formal
# 26   U1027  22.165150 -100.987015   true  social drinker    no preference
# 27   U1028  23.752874  -99.169242  false      abstemious    no preference
# 28   U1029  22.151796 -100.989075   true  casual drinker           formal
# 29   U1030  18.844818  -99.182758  false  casual drinker           formal
# ..     ...        ...         ...    ...             ...              ...
# 108  U1109  22.303308 -101.054680  false      abstemious           formal
# 109  U1110  18.871678  -99.183263  false      abstemious    no preference
# 110  U1111  22.143078 -100.908523   true  casual drinker           formal
# 111  U1112  22.143078 -100.908523   true  casual drinker           formal
# 112  U1113  22.137343 -100.913935  false  casual drinker           formal
# 113  U1114  22.177726 -101.014094  false      abstemious    no preference
# 114  U1115  22.138127 -100.920512   true  social drinker          elegant
# 115  U1116  22.156469 -100.985540  false  social drinker           formal
# 116  U1117  18.875641  -99.220737  false      abstemious    no preference
# 117  U1118  18.940062  -99.228172   true  casual drinker         informal
# 118  U1119  18.964790  -99.260017  false      abstemious           formal
# 119  U1120  22.121857 -100.904279  false      abstemious         informal
# 120  U1121  18.871674  -99.183253  false  social drinker    no preference
# 121  U1122  22.169601 -100.991821      ?      abstemious                ?
# 122  U1123  23.753112  -99.168567  false      abstemious         informal
# 123  U1124  22.137072 -100.918865  false  casual drinker         informal
# 124  U1125  22.192040 -100.956935  false  casual drinker           formal
# 125  U1126  22.154210 -100.942233  false  casual drinker           formal
# 126  U1127  18.943935  -99.206532  false      abstemious    no preference
# 127  U1128  22.187236 -100.994213  false  casual drinker    no preference
# 128  U1129  23.728798  -99.134047  false  casual drinker    no preference
# 129  U1130  23.733000  -99.133000      ?      abstemious                ?
# 130  U1131  22.138245 -100.910948   true  social drinker    no preference
# 131  U1132  22.150000 -100.983000  false  casual drinker         informal
# 132  U1133  18.886698  -99.114979  false      abstemious    no preference
# 133  U1134  22.149654 -100.998610  false  casual drinker    no preference
# 134  U1135  22.170396 -100.949936  false  casual drinker         informal
# 135  U1136  22.149607 -100.997235   true  social drinker    no preference
# 136  U1137  22.144803 -100.944623  false  social drinker           formal
# 137  U1138  22.152884 -100.939663  false  social drinker           formal
#
#      ambience  transport marital_status        hijos  \
# 0      family    on foot         single  independent
# 1      family     public         single  independent
# 2      family     public         single  independent
# 3      family     public         single  independent
# 4      family     public         single  independent
# 5     friends  car owner         single  independent
# 6    solitary     public         single  independent
# 7    solitary     public         single  independent
# 8      family    on foot         single         kids
# 9     friends  car owner        married         kids
# 10     family     public         single  independent
# 11     family     public         single  independent
# 12    friends     public          widow  independent
# 13    friends     public         single  independent
# 14     family     public         single  independent
# 15    friends    on foot         single  independent
# 16     family     public         single            ?
# 17    friends     public         single  independent
# 18     family     public         single  independent
# 19    friends     public         single  independent
# 20     family  car owner         single    dependent
# 21     family  car owner         single  independent
# 22    friends  car owner         single  independent
# 23          ?          ?              ?            ?
# 24     family     public         single            ?
# 25     family     public         single  independent
# 26          ?     public         single  independent
# 27     family     public         single  independent
# 28     family     public         single  independent
# 29     family    on foot         single  independent
# ..        ...        ...            ...          ...
# 108  solitary     public         single  independent
# 109    family  car owner         single  independent
# 110   friends  car owner         single  independent
# 111   friends  car owner         single  independent
# 112    family     public         single  independent
# 113    family    on foot         single  independent
# 114   friends     public         single  independent
# 115    family     public        married         kids
# 116   friends     public         single  independent
# 117   friends     public         single  independent
# 118    family     public         single  independent
# 119   friends     public         single  independent
# 120    family     public        married  independent
# 121         ?          ?              ?            ?
# 122    family          ?         single  independent
# 123   friends     public         single  independent
# 124   friends     public         single  independent
# 125   friends    on foot         single  independent
# 126  solitary     public         single  independent
# 127   friends     public         single  independent
# 128   friends     public         single  independent
# 129         ?          ?              ?            ?
# 130   friends  car owner        married         kids
# 131  solitary     public         single            ?
# 132    family  car owner         single  independent
# 133    family     public         single  independent
# 134    family    on foot         single         kids
# 135   friends  car owner         single  independent
# 136    family     public         single  independent
# 137   friends     public         single  independent
#
#                 ...                   interest          personality  \
# 0               ...                    variety    thrifty-protector
# 1               ...                 technology  hunter-ostentatious
# 2               ...                       none          hard-worker
# 3               ...                    variety          hard-worker
# 4               ...                       none    thrifty-protector
# 5               ...                    variety          hard-worker
# 6               ...                    variety    thrifty-protector
# 7               ...                 technology          hard-worker
# 8               ...                    variety    thrifty-protector
# 9               ...                 technology          hard-worker
# 10              ...                    variety          hard-worker
# 11              ...                 technology          hard-worker
# 12              ...                      retro    thrifty-protector
# 13              ...                       none          hard-worker
# 14              ...                 technology    thrifty-protector
# 15              ...               eco-friendly    thrifty-protector
# 16              ...                      retro  hunter-ostentatious
# 17              ...                 technology    thrifty-protector
# 18              ...                    variety    thrifty-protector
# 19              ...                 technology          hard-worker
# 20              ...                       none          hard-worker
# 21              ...                    variety          hard-worker
# 22              ...                       none          hard-worker
# 23              ...                       none          hard-worker
# 24              ...                       none    thrifty-protector
# 25              ...                 technology  hunter-ostentatious
# 26              ...                      retro    thrifty-protector
# 27              ...                    variety          hard-worker
# 28              ...                    variety           conformist
# 29              ...               eco-friendly          hard-worker
# ..              ...                        ...                  ...
# 108             ...               eco-friendly    thrifty-protector
# 109             ...                    variety    thrifty-protector
# 110             ...                       none          hard-worker
# 111             ...                       none          hard-worker
# 112             ...                       none    thrifty-protector
# 113             ...                    variety          hard-worker
# 114             ...                    variety          hard-worker
# 115             ...                 technology    thrifty-protector
# 116             ...                 technology    thrifty-protector
# 117             ...                 technology    thrifty-protector
# 118             ...               eco-friendly    thrifty-protector
# 119             ...                    variety          hard-worker
# 120             ...                    variety    thrifty-protector
# 121             ...                       none          hard-worker
# 122             ...                 technology          hard-worker
# 123             ...                       none          hard-worker
# 124             ...                 technology          hard-worker
# 125             ...                 technology          hard-worker
# 126             ...                    variety          hard-worker
# 127             ...                    variety    thrifty-protector
# 128             ...                    variety    thrifty-protector
# 129             ...                       none          hard-worker
# 130             ...               eco-friendly          hard-worker
# 131             ...                       none          hard-worker
# 132             ...                       none          hard-worker
# 133             ...                    variety          hard-worker
# 134             ...                    variety  hunter-ostentatious
# 135             ...                      retro    thrifty-protector
# 136             ...               eco-friendly          hard-worker
# 137             ...                    variety    thrifty-protector
#
#       religion       activity   color weight  budget height  \
# 0         none        student   black     69  medium   1.77
# 1     Catholic        student     red     40     low   1.87
# 2     Catholic        student    blue     60     low   1.69
# 3         none   professional   green     44  medium   1.53
# 4     Catholic        student   black     65  medium   1.69
# 5         none        student    blue     75  medium   1.80
# 6     Catholic        student  purple     60     low   1.59
# 7     Catholic        student   green     68     low   1.72
# 8     Catholic        student   green     75  medium   1.78
# 9         none        student   green     40  medium   1.67
# 10    Catholic        student  purple     68  medium   1.78
# 11    Catholic        student     red     98  medium   1.84
# 12        none   professional    blue     80  medium   1.75
# 13    Catholic        student    blue     53  medium   1.69
# 14    Catholic        student   black     87  medium   1.67
# 15    Catholic        student   green     70  medium   1.67
# 16        none   professional  orange     79  medium   1.79
# 17   Christian        student    blue     65     low   1.83
# 18    Catholic        student  purple     59  medium   1.60
# 19    Catholic   professional    blue     40  medium   1.68
# 20    Catholic        student  purple    108  medium   1.62
# 21    Catholic        student  purple     46  medium   1.54
# 22    Catholic        student    blue    103     low   1.79
# 23        none              ?  yellow     40       ?   1.20
# 24    Catholic        student     red     65  medium   1.79
# 25    Catholic        student     red     49  medium   1.55
# 26    Catholic        student  purple     60     low   1.65
# 27   Christian        student    blue     77  medium   1.63
# 28    Catholic        student   white     58     low   1.60
# 29    Catholic        student   black     64  medium   1.75
# ..         ...            ...     ...    ...     ...    ...
# 108   Catholic        student    blue     57     low   1.72
# 109   Catholic        student     red     85  medium   1.75
# 110   Catholic        student   white     69  medium   1.69
# 111   Catholic        student   white     69  medium   1.69
# 112   Catholic        student    blue     75  medium   1.73
# 113   Catholic        student    blue     58  medium   1.68
# 114   Catholic        student   green     76     low   1.76
# 115   Catholic        student    blue     40  medium   1.71
# 116   Catholic   professional    blue     58  medium   1.60
# 117       none        student   black     60  medium   1.68
# 118   Catholic        student    blue     68  medium   1.68
# 119       none        student   green     47     low   1.57
# 120   Catholic  working-class   black     90  medium   1.60
# 121       none              ?  yellow     40       ?   1.20
# 122   Catholic        student   green    110  medium   1.75
# 123   Catholic        student    blue     51     low   1.20
# 124   Catholic        student   white     57     low   1.67
# 125   Catholic        student  purple     65     low   1.63
# 126   Catholic        student   black     65     low   1.76
# 127   Catholic        student     red     66     low   1.72
# 128       none        student  purple     69     low   1.69
# 129       none              ?  yellow     40       ?   1.20
# 130       none        student   black     90  medium   1.80
# 131       none        student    blue     55       ?   1.60
# 132       none        student  orange     60  medium   1.57
# 133   Catholic        student   black     52  medium   1.65
# 134   Catholic        student  purple     66     low   1.54
# 135   Catholic        student   black     50     low   1.60
# 136   Catholic        student    blue     72     low   1.78
# 137       none        student    blue     54  medium   1.55
#
#                                                Cuisine  \
# 0                                            American
# 1                                             Mexican
# 2                                             Mexican
# 3    Bakery Breakfast-Brunch Japanese Contemporary ...
# 4                                            American
# 5                                             Mexican
# 6                                              Family
# 7    Cafe-Coffee_Shop Mexican Juice Hawaiian Hot_Do...
# 8    Diner Fast_Food Family Cafe-Coffee_Shop Deli-S...
# 9                                             Mexican
# 10                                            Mexican
# 11                                     Latin_American
# 12                                           Japanese
# 13                                 Japanese Fast_Food
# 14                                            Mexican
# 15   Cafe-Coffee_Shop Contemporary Regional Fusion ...
# 16                                            Chinese
# 17                                            Mexican
# 18                                             Family
# 19                                            Mexican
# 20                  Pizzeria Regional Chinese Burgers
# 21                                            Mexican
# 22                                            Mexican
# 23                                             Afghan
# 24                                            Mexican
# 25                                            Mexican
# 26                                             Family
# 27                                            Mexican
# 28                                            Mexican
# 29                                            Mexican
# ..                                                 ...
# 108                                           Mexican
# 109                                           Mexican
# 110                                           Mexican
# 111                                           Mexican
# 112                                           Burgers
# 113                                           Mexican
# 114                                          Regional
# 115                                           Mexican
# 116                                           Turkish
# 117                                          Pizzeria
# 118                                           Mexican
# 119                                           Mexican
# 120                                           Mexican
# 121                                            Afghan
# 122                                           Mexican
# 123                                           Mexican
# 124                                           Mexican
# 125                                           Mexican
# 126                                           Mexican
# 127               Cafeteria Hot_Dogs Pizzeria Mexican
# 128                                           Mexican
# 129                                           Mexican
# 130                                           Mexican
# 131                                           Mexican
# 132                                           Mexican
# 133                                           Mexican
# 134  Organic-Healthy Steaks Middle_Eastern Mediterr...
# 135                                           Mexican
# 136                                           Mexican
# 137                                          Pizzeria
#
#                          Payment
# 0                          cash
# 1                          cash
# 2                          cash
# 3         cash bank_debit_cards
# 4                          cash
# 5                          cash
# 6                          cash
# 7                          cash
# 8                          cash
# 9                          cash
# 10                         cash
# 11        cash bank_debit_cards
# 12     MasterCard-Eurocard cash
# 13                         cash
# 14                         cash
# 15                         cash
# 16                    cash VISA
# 17                         cash
# 18                         cash
# 19        cash bank_debit_cards
# 20                         cash
# 21                         cash
# 22                         cash
# 23
# 24
# 25        cash bank_debit_cards
# 26                         cash
# 27                         cash
# 28                         cash
# 29                         cash
# ..                           ...
# 108                        cash
# 109                        cash
# 110                        cash
# 111                        cash
# 112                   VISA cash
# 113                        cash
# 114                        cash
# 115  cash bank_debit_cards VISA
# 116       bank_debit_cards cash
# 117                        cash
# 118                        cash
# 119                        cash
# 120       cash bank_debit_cards
# 121
# 122                        cash
# 123                        cash
# 124                        cash
# 125                        cash
# 126                        cash
# 127                        cash
# 128                        cash
# 129
# 130                        cash
# 131                        cash
# 132       bank_debit_cards cash
# 133                        cash
# 134                        cash
# 135                        cash
# 136                        cash
# 137                        cash
#
# [138 rows x 21 columns]

# %%
user_profile.columns
# Out:
# Index(['userID', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_preference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'interest', 'personality', 'religion', 'activity',
#        'color', 'weight', 'budget', 'height', 'Cuisine', 'Payment'],
#       dtype='object')

# %%
rest_profile.columns
# Out:
# Index(['placeID', 'latitude', 'longitude', 'the_geom_meter', 'name', 'address',
#        'city', 'state', 'country', 'fax', 'zip', 'alcohol', 'smoking_area',
#        'dress_code', 'accessibility', 'price', 'url', 'Rambience', 'franchise',
#        'area', 'other_services', 'Cuisine', 'Payment', 'Parking'],
#       dtype='object')

# %%
ratings = pd.read_csv(rating_dir)

# %%
from sklearn.model_selection import train_test_split
rating_train, rating_test = train_test_split(ratings, test_size=0.3)

# %%
n_users = len(ratings.userID.unique())
n_items = len(ratings.placeID.unique())
print (n_users)
print (n_items)
# Out:
# 138
# 130

# %%
user_list = np.array(ratings.userID.unique())
item_list = np.array(ratings.placeID.unique())

# %%
user_profile.columns
# Out:
# Index(['userID', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_preference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'interest', 'personality', 'religion', 'activity',
#        'color', 'weight', 'budget', 'height', 'Cuisine', 'Payment'],
#       dtype='object')

# %%
rest_profile.columns
# Out:
# Index(['placeID', 'latitude', 'longitude', 'the_geom_meter', 'name', 'address',
#        'city', 'state', 'country', 'fax', 'zip', 'alcohol', 'smoking_area',
#        'dress_code', 'accessibility', 'price', 'url', 'Rambience', 'franchise',
#        'area', 'other_services', 'Cuisine', 'Payment', 'Parking'],
#       dtype='object')

# %%
rest_profile.price.value_counts()
# Out:
# medium    60
# low       45
# high      25
# Name: price, dtype: int64

# %%
def get_context(user, rest, user_profile, rest_profile):
    this_user = user_profile[user_profile['userID']==user]
    this_rest = rest_profile[rest_profile['placeID'] == rest]
    
    #print (this_user)
    #print (this_rest)
    contexts = 0
    
    if this_user['smoker'].item() == 'true' and (this_rest['smoking_area'].item() == 'section'or this_rest['smoking_area'].item() == 'permitted' or this_rest['smoking_area'].item() == 'only at bar'):
        contexts = contexts + 1
    
    if (this_user['drink_level'].item() == 'casual drinker' or this_user['drink_level'].item() == 'social_drinker') and this_rest['alcohol'].item() == 'Wine-Beer' or this_rest['alcohol'].item() == 'Full_Bar':
        contexts = contexts + 1 
    
    if (this_user['dress_preference'].item() == 'formal' or this_user['dress_preference'].item() == 'elegant') and (this_rest['dress_code'].item() == 'formal' or this_rest['Rambience'].item() == 'quiet' or this_rest['franchise'].item()== 'f'):
        contexts = contexts + 1 
        
    if (this_user['dress_preference'].item() == 'informal') and (this_rest['dress_code'].item() == 'informal' or this_rest['dress_code'].item() == 'casual'):
        contexts = contexts + 1 
    
    if (this_user['ambience'].item() == 'family' or this_user['ambience'].item() == 'friends') and (this_rest['Rambience'].item() == 'familiar'):
        contexts = contexts + 1 
    
    if (this_user['ambience'].item() == 'solitary') and (this_rest['Rambience'].item() == 'quiet'):
        contexts = contexts + 1
    
    if (this_user['transport'].item() == 'car owner') and (this_rest['Parking'].item() == 'yes' or this_rest['Parking'].item() == 'public' or this_rest['Parking'].item() == 'valet parking'):
        contexts = contexts + 1 
        
    if (this_user['activity'].item() == 'student' or this_user['activity'].item() == 'working class') and (this_rest['price'].item() == 'low' or this_rest['price'].item() == 'medium'):
        contexts = contexts + 1 
    
    if (this_user['activity'].item() == 'unemployed') and (this_rest['price'].item() == 'low'):
        contexts = contexts + 1 
    
    if (this_user['activity'].item() == 'professional') and (this_rest['price'].item() == 'medium' or this_rest['price'].item() == 'high'):
        contexts = contexts + 1 
    
    if (this_user['budget'].item() == 'high') and (this_rest['price'].item() == 'high'):
        contexts = contexts + 1 
    
    if (this_user['budget'].item() == 'medium') and (this_rest['price'].item() == 'medium'):
        contexts = contexts + 1 
    
    if (this_user['budget'].item() == 'low') and (this_rest['price'].item() == 'low' or this_rest['franchise'].item() == 't'):
        contexts + contexts + 1 
        
    this_user_cuisines = this_user['Cuisine'].item().split(' ')
    this_rest_cuisines = this_rest['Cuisine'].item()
    
    this_user_payment = this_user['Payment'].item().split(' ')
    this_rest_payment = this_rest['Payment'].item()
    
    for j in range(len(this_user_cuisines)-1):
        if this_user_cuisines[j] in this_rest_cuisines:
            contexts = contexts + 1
    
    for m in range(len(this_user_payment)-1):
        if this_user_payment[m] in this_rest_payment:
            contexts = contexts + 1 
        
    return contexts

# %%
from scipy.sparse import rand as sprand
from scipy.sparse import lil_matrix

# %%
#do we need to create contexts for the entirety of the restaurants?

# %%
contexts_full = lil_matrix((n_users, n_items), dtype = float)
for i in range(len(user_list)):
    for j in range(len(item_list)):
        contexts_full[i, j] = get_context(user_list[i], item_list[j], user_profile, rest_profile)

# %%
context_dense = contexts_full.todense()

# %%
np.max(context_dense)
# Out:
# 11.0

# %%
np.mean(context_dense)
# Out:
# 3.6567447045707917

# %%
contexts_norm = lil_matrix((n_users, n_items), dtype = float)
for i in range(len(user_list)):
    for j in range(len(item_list)):
        contexts_norm[i, j] = (get_context(user_list[i], item_list[j], user_profile, rest_profile))/11.0

# %%
interactions_full_orig = lil_matrix((n_users, n_items), dtype = float)
for row in ratings.itertuples():
    user, = np.where(user_list == row[1])
    item, = np.where(item_list == row[2])
    interactions_full_orig[user[0], item[0]] = row[3]

# %%
interactions_train_orig = lil_matrix((n_users, n_items), dtype = float)
context_train = lil_matrix((n_users, n_items), dtype = float)
for row in rating_train.itertuples():
    user, = np.where(user_list == row[1])
    item, = np.where(item_list == row[2])
    context_train[user[0], item[0]] = get_context(row[1], row[2], user_profile, rest_profile)
    interactions_train_orig[user[0], item[0]] = row[3]

# %%
#original ratings
interactions_test_orig = lil_matrix((n_users, n_items), dtype = float)
context_test = lil_matrix((n_users, n_items), dtype = float)
for row in rating_test.itertuples():
    user, = np.where(user_list == row[1])
    item, = np.where(item_list == row[2])
    interactions_test_orig[user[0], item[0]] = row[3]
    context_test[user[0], item[0]] = get_context(row[1], row[2], user_profile, rest_profile)

# %%
class MatrixFactorization(torch.nn.Module):
    
    def __init__(self, n_users, n_items, n_factors=5):
        super().__init__()
        self.user_factors = torch.nn.Embedding(n_users,
                                               n_factors,
                                               sparse=False)
        self.item_factors = torch.nn.Embedding(n_items,n_factors,sparse=False)
                  

    # I NEED TO IMPLEMENT THE PREDICTION based on context
    def predict(self, user, item):
        # Need to fit bias factors
        #pred = (self.user_factors(user) * self.item_factors(item)).sum(1)
        
        #context = (self.user_context(user) * self.item_(item)).sum(1)
        return (self.user_factors(user) * self.item_factors(item)).sum(1)
    
    # Much more efficient batch operator. This should be used for training purposes
    
    def forward(self, users, items, context):
        #return (self.user_factors(user) * self.item_factors(item)).sum(1)
    
        orig = torch.mm(self.user_factors(users),torch.transpose(self.item_factors(items),0,1))
        
        #here = torch.from_numpy(context)
        #context = torch.mm(self.user_context(users), torch.transpose(self.item_context(items),0,1))
        
        #fused_context = context * self.fusion.expand_as(context)
        
        mat = torch.add(orig, context)
        return mat
        #return torch.mm(self.user_factors(users),torch.transpose(self.item_factors(items),0,1))

# %%
class BiasedMatrixFactorization(torch.nn.Module):
    
    def __init__(self, n_users, n_items,mean, n_factors=5):
        super().__init__()
        self.user_factors = torch.nn.Embedding(n_users,
                                               n_factors,
                                               sparse=False)
        self.item_factors = torch.nn.Embedding(n_items, n_factors,sparse=False)
        self.user_biases = torch.nn.Embedding(n_users, 1, sparse = False)
        
        self.item_biases = torch.nn.Embedding(n_items,1, sparse = False)
                                               
        self.mu = mean
    
    #need to change this predict function    
    def predict(self, user, item):
        pred = self.mu + self.user_biases(user) + self.item_biases(item)
        orig = (self.user_factors(user) * self.item_factors(item)).sum(1)
        final = pred + orig
        return final
    
    def forward(self, users, items, context):
        
        item_means = []
        user_means = []
        for i in range(len(users)):
            item_means.append(torch.t(self.item_biases(items)))
            
        for j in range(len(items)):
            user_means.append(torch.t(self.user_biases(users)))
        
        it_means = torch.cat(item_means, 0)
        us_means = torch.cat(user_means, 0)
        us_means = torch.t(us_means)
        
        orig = torch.mm(self.user_factors(users),torch.transpose(self.item_factors(items),0,1))
        
        y = torch.add(orig, it_means)
        
        f = torch.add(y,us_means)
        
        result = torch.add(f,self.mu)
        
        mat = torch.add(result, context)
        
        return mat

# %%
def get_batch(batch_size,ratings):
    # Sort our data and scramble it
    rows, cols = ratings.shape
    p = np.random.permutation(rows)
    
    # create batches
    sindex = 0
    eindex = batch_size
    while eindex < rows:
        batch = p[sindex:eindex]
        temp = eindex
        eindex = eindex + batch_size
        sindex = temp
        yield batch

    if eindex >= rows:
        batch = range(sindex,rows)
        yield batch

# %%
def load_model(model,load_path):
    load_dict = torch.load(load_path)
    val_loss = load_dict['val_loss']
    #for key in load_dict.keys():
       # print (key)
    model.load_state_dict(load_dict['model_state_dict'])


def checkpoint_model(val_loss, model,save_path):
    save_dict = dict(
                     val_loss=val_loss,
                     model_state_dict=model.state_dict())
                     #opt_state_dict=predictions.state_dict())
    torch.save(save_dict, save_path)

# %%
def run_validation(model, test_ratings, context_mat, fusion, BATCH_SIZE, load_path):
    load_model(model, load_path)
    running_loss = 0.0
    loss_func = torch.nn.MSELoss()
    accur = 0
    for i,batch in enumerate(get_batch(BATCH_SIZE, test_ratings)):
        
        interactions = Variable(torch.FloatTensor(test_ratings[batch, :].toarray()))
        rows = Variable(torch.LongTensor(batch))
        cols = Variable(torch.LongTensor(np.arange(test_ratings.shape[1])))
        
        first = (context_mat[batch,:].toarray())*fusion
        contexts = Variable(torch.FloatTensor(first))
        
        
        predictions = model(rows, cols, contexts)
        loss = loss_func(predictions, interactions)
        
        running_loss += np.sqrt(loss.data[0])*BATCH_SIZE
        
        correct = get_accuracy_test(test_ratings, model, rows, fusion, context_mat)
        accur = accur+ correct
    
    epoch_loss = running_loss/test_ratings.shape[0]
    return epoch_loss,accur

# %%
#when using the food + service ratings (not used right now)
def run_validation_test(model, test_ratings, test_ratings_orig, BATCH_SIZE, load_path):
    load_model(model, load_path)
    running_loss = 0.0
    loss_func = torch.nn.MSELoss()
    accur = 0
    for i,batch in enumerate(get_batch(BATCH_SIZE, test_ratings)):
        
        interactions = Variable(torch.FloatTensor(test_ratings[batch, :].toarray()))
        rows = Variable(torch.LongTensor(batch))
        cols = Variable(torch.LongTensor(np.arange(test_ratings.shape[1])))
        
        predictions = model(rows, cols)
        loss = loss_func(predictions, interactions)
        
        running_loss += np.sqrt(loss.data[0])*BATCH_SIZE
        
        correct = get_accuracy_test(test_ratings_orig, model, rows)
        accur = accur+ correct
    
    epoch_loss = running_loss/test_ratings.shape[0]
    return epoch_loss,accur

# %%
def get_accuracy_test(interactions_orig,model,rows,fusion, contexts_full):
    
    checks = np.nonzero(interactions_orig)
    check_these = checks[0]
    
    batch = range(interactions_orig.shape[0])
    interactions = Variable(torch.FloatTensor(interactions_orig[batch,:].toarray()))
    users = Variable(torch.LongTensor(batch))
    cols = Variable(torch.LongTensor(np.arange(interactions_orig.shape[1])))
    
    first = (contexts_full[batch,:].toarray())*fusion
    contexts = Variable(torch.FloatTensor(first))
    
    predictions = model(users, cols, contexts)
    
    x = predictions.data.numpy()
    
    correct = 0
    
    for u in range(len(rows)):
        user = rows.data[u]
        where = np.where(check_these==user)
        index = where[0]
        if len(index) > 0:
            for c in range(len(index)):
                rest = checks[1][index[c]]
                prediction = predictions[u][rest]
                   
                val = prediction.data[0]
                
                if val <= np.percentile(x,22):
                    this_val = 0.0
                elif np.percentile(x,22) < val < np.percentile(x, 58):
                    this_val = 1.0
                elif val >= np.percentile(x, 58):
                     this_val= 2.0
        
                
                if this_val == interactions_orig[user,rest]:
                    correct = correct + 1 
            else:
                next
    return correct

# %%
def generate_predictions(model, contexts_full, interactions_full, load_path):
    load_model(model, load_path)

    batch = range(interactions_full.shape[0])
    interactions = Variable(torch.FloatTensor(interactions_full[batch,:].toarray()))
    rows = Variable(torch.LongTensor(batch))
    cols = Variable(torch.LongTensor(np.arange(interactions_full.shape[1])))
    first = (contexts_full[batch,:].toarray())*fusion
        
    #contexts = Variable(torch.FloatTensor(contexts_full[batch,:].toarray()))
    contexts = Variable(torch.FloatTensor(first))
        
    predictions = model(rows, cols, contexts)
    
    predictions[interactions!=0] = 0
        
    val, index = torch.sort(predictions,1, descending = True)
        
    top5 = index[:,:5]
        
    return top5

# %%
def give_top5_cuisines(recs, name_list, cuisine_list, user_list, rest_list):
    your_rests = [[0 for j in range(11)] for u in range(len(user_list))]
    for i in range(len(user_list)):
        user, = np.where(user_list == user_list[i])
        your_rests[i][0] = user_list[i]
        count = 1
        for r in range(5):
            this_rest = recs[user[0]][r].data[0]
            rest = rest_list[this_rest]
            x = name_list.loc[name_list['placeID'] == rest]
            name = x['name'].item()
            
            your_rests[i][count] = name
            count = count +1
            
            y = cuisine_list.loc[cuisine_list['placeID'] == rest]['Rcuisine']
            
            cuisine_types = ''
            for m in y:
                cuisine_types = cuisine_types + m + ', '
            
            your_rests[i][count] = cuisine_types
            count = count + 1
            
    return your_rests

# %%
def give_number_of_contexts(recs, context, this_user,user_list, rest_list):
   
    
    contexts = [0 for i in range(5)]
    
    user, = np.where(this_user == user_list)
    print (user)
    
    for u in range(5):
        this_rest = recs[user[0]][u].data[0]

        
        contexts[u] = context[user[0], this_rest]
    
    return contexts

# %%
batch_size = 10
save_path = './project_models/model.ckpt'
save_path_val = './project_models/modelv.ckpt'
factors = [2,3,4,5]
fusion_arr = [0.0,0.25,0.5, 0.75, 1.0]

# %%
checks = np.nonzero(interactions_train_orig)
checks_v = np.nonzero(interactions_test_orig)

# %%
#original ratings
best_val_loss = 1000.0
best_val_accuracy = 0.0
for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(4,5):  
        fusion = fusion_arr[f]
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = MatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1], n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            #best_train_loss = 1000.0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_orig)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_orig[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_orig.shape[1])))
                first = (contexts_full[batch,:].toarray())*fusion
        
                #contexts = Variable(torch.FloatTensor(contexts_full[batch,:].toarray()))
                contexts = Variable(torch.FloatTensor(first))
        
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_orig.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path)
        
            val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path)
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full, fusion, batch_size, save_path)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                #checkpoint_model(val_loss, model, save_path_val)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy) + ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 1.0
# Epoch: 0
# train_loss: 4.154512987684978
# accuracy:0.43553459119496857
# checkpoint model with train loss: 4.154512987684978
# val_loss
# model_state_dict
# val loss: 4.1530918656704445
# val accuracy: 0.4280442804428044
# checkpointing_model with val loss: 4.1530918656704445
# New Best Val Accuracy: 0.4280442804428044 with fusion: 1.0 and factor :2
# Epoch: 1
# train_loss: 4.1685440026251115
# accuracy:0.47641509433962265
# val_loss
# model_state_dict
# val loss: 4.1710205874808075
# val accuracy: 0.4132841328413284
# Epoch: 2
# train_loss: 4.138551853536699
# accuracy:0.41037735849056606
# checkpoint model with train loss: 4.138551853536699
# val_loss
# model_state_dict
# val loss: 4.178910003883664
# val accuracy: 0.4059040590405904
# Epoch: 3
# train_loss: 4.14800541741125
# accuracy:0.4418238993710692
# val_loss
# model_state_dict
# val loss: 4.165817260447621
# val accuracy: 0.3985239852398524
# Epoch: 4
# train_loss: 4.152707541228331
# accuracy:0.46226415094339623
# val_loss
# model_state_dict
# val loss: 4.151061227824469
# val accuracy: 0.36162361623616235
# checkpointing_model with val loss: 4.151061227824469

# %%
recs = generate_predictions(model, contexts_full, interactions_full_orig, save_path_val)
results = give_top5_cuisines(recs, rest_profile, rest_cuisine, user_list, item_list)
# Out:
# val_loss
# model_state_dict

# %%
give_number_of_contexts(recs, contexts_full, 'U1093', user_list,item_list)
# Out:
# [18]
# [7.0, 6.0, 6.0, 6.0, 6.0]

# %%
give_number_of_contexts(recs, contexts_full, 'U1077', user_list,item_list)
# Out:
# [0]
# [9.0, 6.0, 8.0, 7.0, 7.0]

# %%
col_names = ['User','Rec1', 'Rec1_Cuisines', 'Rec2', 'Rec2_Cuisines', 'Rec3', 'Rec3_Cuisines', 'Rec4','Rec4_Cuisines',  'Rec5', 'Rec5_Cuisines']

# %%
df = pd.DataFrame(results,columns = col_names)

# %%
df
# Out:
#       User                                 Rec1           Rec1_Cuisines  \
# 0    U1077                     El Oceano Dorado               Mexican,
# 1    U1068                          La Virreina               Mexican,
# 2    U1067                 La Estrella de Dimas               Mexican,
# 3    U1103                 La Estrella de Dimas               Mexican,
# 4    U1107                 La Estrella de Dimas               Mexican,
# 5    U1044                     El Oceano Dorado               Mexican,
# 6    U1070                          La Virreina               Mexican,
# 7    U1031                          La Virreina               Mexican,
# 8    U1082                        carnitas_mata               Mexican,
# 9    U1023                 Restaurant Orizatlan               Mexican,
# 10   U1060              Restaurante El Reyecito             Fast_Food,
# 11   U1015                    Gordas de morales               Mexican,
# 12   U1123              Restaurante El Reyecito             Fast_Food,
# 13   U1021                        Dominos Pizza              Pizzeria,
# 14   U1026                     El Oceano Dorado               Mexican,
# 15   U1083                          rockabilly                    Bar,
# 16   U1108               Restaurante la Cantina  Bar, Bar_Pub_Brewery,
# 17   U1012                            Luna Cafe        Bar, Cafeteria,
# 18   U1093               Restaurante la Cantina  Bar, Bar_Pub_Brewery,
# 19   U1030                 Restaurant Orizatlan               Mexican,
# 20   U1066                   Mariscos Tia Licha                Family,
# 21   U1127                          rockabilly                    Bar,
# 22   U1017                     El Oceano Dorado               Mexican,
# 23   U1100  Cenaduria El RincÃ³n de Tlaquepaque               Mexican,
# 24   U1133                     El Oceano Dorado               Mexican,
# 25   U1118               Restaurante la Cantina  Bar, Bar_Pub_Brewery,
# 26   U1072                     El Oceano Dorado               Mexican,
# 27   U1080                 La Estrella de Dimas               Mexican,
# 28   U1063                          La Virreina               Mexican,
# 29   U1074                            Luna Cafe        Bar, Cafeteria,
# ..     ...                                  ...                     ...
# 108  U1091                          La Virreina               Mexican,
# 109  U1027                          El cotorreo       Family, Mexican,
# 110  U1029                     El Oceano Dorado               Mexican,
# 111  U1086  Cenaduria El RincÃ³n de Tlaquepaque               Mexican,
# 112  U1137  Cenaduria El RincÃ³n de Tlaquepaque               Mexican,
# 113  U1090              Restaurante El Reyecito             Fast_Food,
# 114  U1061                     El Oceano Dorado               Mexican,
# 115  U1041               Restaurante la Cantina  Bar, Bar_Pub_Brewery,
# 116  U1059              Restaurante El Reyecito             Fast_Food,
# 117  U1112                          La Virreina               Mexican,
# 118  U1057                     El Oceano Dorado               Mexican,
# 119  U1025                        carnitas_mata               Mexican,
# 120  U1097              Restaurante El Reyecito             Fast_Food,
# 121  U1006                     El Oceano Dorado               Mexican,
# 122  U1131                        carnitas_mata               Mexican,
# 123  U1073                   tacos los volcanes              American,
# 124  U1058  Cenaduria El RincÃ³n de Tlaquepaque               Mexican,
# 125  U1002                     El Oceano Dorado               Mexican,
# 126  U1096                 La Estrella de Dimas               Mexican,
# 127  U1136                     El Oceano Dorado               Mexican,
# 128  U1010  Cenaduria El RincÃ³n de Tlaquepaque               Mexican,
# 129  U1028                          La Virreina               Mexican,
# 130  U1050                      Cabana Huasteca               Mexican,
# 131  U1129              Restaurante El Reyecito             Fast_Food,
# 132  U1087                          rockabilly                    Bar,
# 133  U1065                          La Virreina               Mexican,
# 134  U1039                   Mariscos Tia Licha                Family,
# 135  U1130                 La Estrella de Dimas               Mexican,
# 136  U1043                          rockabilly                    Bar,
# 137  U1011                          La Virreina               Mexican,
#
#                                     Rec2              Rec2_Cuisines  \
# 0                Restaurante El Reyecito                Fast_Food,
# 1                              emilianos          Bar_Pub_Brewery,
# 2                            La Virreina                  Mexican,
# 3                       El Oceano Dorado                  Mexican,
# 4                            La Virreina                  Mexican,
# 5                                Sirlone            International,
# 6                                Sirlone            International,
# 7                           don burguers
# 8                            La Virreina                  Mexican,
# 9                       El Oceano Dorado                  Mexican,
# 10                      El Oceano Dorado                  Mexican,
# 11                      El Oceano Dorado                  Mexican,
# 12                       Cabana Huasteca                  Mexican,
# 13           Restaurant Oriental Express                  Chinese,
# 14               Restaurante El Reyecito                Fast_Food,
# 15                      El Oceano Dorado                  Mexican,
# 16                  La Estrella de Dimas                  Mexican,
# 17               Restaurante El Reyecito                Fast_Food,
# 18            Michiko Restaurant Japones                 Japanese,
# 19                             Luna Cafe           Bar, Cafeteria,
# 20                      El Oceano Dorado                  Mexican,
# 21                  tacos de la estacion                  Mexican,
# 22               Restaurante El Reyecito                Fast_Food,
# 23                           El cotorreo          Family, Mexican,
# 24               Restaurante El Reyecito                Fast_Food,
# 25    Cafeteria y Restaurant El Pacifico  Cafeteria, Contemporary,
# 26                  Restaurant Orizatlan                  Mexican,
# 27        Restaurante Casa de las Flores
# 28                  La Estrella de Dimas                  Mexican,
# 29          Restaurant Familiar El Chino               Vietnamese,
# ..                                   ...                        ...
# 108                        carnitas_mata                  Mexican,
# 109               Restaurante la Cantina     Bar, Bar_Pub_Brewery,
# 110                    Gordas de morales                  Mexican,
# 111                la perica hamburguesa                  Italian,
# 112                          El cotorreo          Family, Mexican,
# 113                     El Oceano Dorado                  Mexican,
# 114                 Restaurant Orizatlan                  Mexican,
# 115                 La Estrella de Dimas                  Mexican,
# 116                     El Oceano Dorado                  Mexican,
# 117                 La Estrella de Dimas                  Mexican,
# 118                    Gordas de morales                  Mexican,
# 119                 La Estrella de Dimas                  Mexican,
# 120                     El Oceano Dorado                  Mexican,
# 121                    Gordas de morales                  Mexican,
# 122                          La Virreina                  Mexican,
# 123                          rockabilly                       Bar,
# 124       Restaurante Casa de las Flores
# 125                                 vips                  Mexican,
# 126                          La Virreina                  Mexican,
# 127                         don burguers
# 128                      Cabana Huasteca                  Mexican,
# 129                              Sirlone            International,
# 130              Restaurante El Reyecito                Fast_Food,
# 131                     El Oceano Dorado                  Mexican,
# 132              Restaurante El Reyecito                Fast_Food,
# 133                 La Estrella de Dimas                  Mexican,
# 134                         don burguers
# 135  Cenaduria El RincÃ³n de Tlaquepaque                  Mexican,
# 136              Restaurante El Reyecito                Fast_Food,
# 137                        carnitas_mata                  Mexican,
#
#                                     Rec3                  Rec3_Cuisines  \
# 0                      Gordas de morales                      Mexican,
# 1                   La Estrella de Dimas                      Mexican,
# 2                          carnitas_mata                      Mexican,
# 3                            La Virreina                      Mexican,
# 4                              emilianos              Bar_Pub_Brewery,
# 5                 La Cantina Restaurante         Bar, Bar_Pub_Brewery,
# 6                   La Estrella de Dimas                      Mexican,
# 7                          carnitas_mata                      Mexican,
# 8                                Sirlone                International,
# 9                      Gordas de morales                      Mexican,
# 10              Preambulo Wifi Zone Cafe  Cafe-Coffee_Shop, Cafeteria,
# 11                Restaurante la Cantina         Bar, Bar_Pub_Brewery,
# 12                           rockabilly                           Bar,
# 13                Restaurante la Cantina         Bar, Bar_Pub_Brewery,
# 14                    Mariscos Tia Licha                       Family,
# 15                                  vips                      Mexican,
# 16                             emilianos              Bar_Pub_Brewery,
# 17                  Restaurant Orizatlan                      Mexican,
# 18                  Restaurant Orizatlan                      Mexican,
# 19   Cenaduria El RincÃ³n de Tlaquepaque                      Mexican,
# 20                               Sirlone                International,
# 21                     Cafeteria cenidet                    Cafeteria,
# 22                     Gordas de morales                      Mexican,
# 23                             Luna Cafe               Bar, Cafeteria,
# 24                     Gordas de morales                      Mexican,
# 25        Restaurante Casa de las Flores
# 26                     Gordas de morales                      Mexican,
# 27                           La Virreina                      Mexican,
# 28                           el pueblito                      Mexican,
# 29                             shi ro ie                     Japanese,
# ..                                   ...                            ...
# 108                              Sirlone                International,
# 109                    Gordas de morales                      Mexican,
# 110                         don burguers
# 111               Restaurante la Cantina         Bar, Bar_Pub_Brewery,
# 112       Restaurante Casa de las Flores
# 113                    Gordas de morales                      Mexican,
# 114                la perica hamburguesa                      Italian,
# 115                             Carls Jr                      Burgers,
# 116                          rockabilly                           Bar,
# 117       Restaurante Casa de las Flores
# 118                              Sirlone                International,
# 119                            tacos abi                      Mexican,
# 120                    Gordas de morales                      Mexican,
# 121                                 vips                      Mexican,
# 122                    Gordas de morales                      Mexican,
# 123                            Paniroles                      Italian,
# 124               Restaurante la Cantina         Bar, Bar_Pub_Brewery,
# 125                    Gordas de morales                      Mexican,
# 126  Cenaduria El RincÃ³n de Tlaquepaque                      Mexican,
# 127                   Mariscos Tia Licha                       Family,
# 128                    Gordas de morales                      Mexican,
# 129                 La Estrella de Dimas                      Mexican,
# 130                la perica hamburguesa                      Italian,
# 131                      puesto de tacos                      Mexican,
# 132             Preambulo Wifi Zone Cafe  Cafe-Coffee_Shop, Cafeteria,
# 133                        carnitas_mata                      Mexican,
# 134               Tortas Locas Hipocampo                    Fast_Food,
# 135                          El cotorreo              Family, Mexican,
# 136             Preambulo Wifi Zone Cafe  Cafe-Coffee_Shop, Cafeteria,
# 137                 La Estrella de Dimas                      Mexican,
#
#                                     Rec4           Rec4_Cuisines  \
# 0                   Restaurant Orizatlan               Mexican,
# 1                            el pueblito               Mexican,
# 2    Cenaduria El RincÃ³n de Tlaquepaque               Mexican,
# 3                      Gordas de morales               Mexican,
# 4                          carnitas_mata               Mexican,
# 5                                   vips               Mexican,
# 6                            el pueblito               Mexican,
# 7                                   vips               Mexican,
# 8                   cafe punta del cielo             Cafeteria,
# 9                                   vips               Mexican,
# 10                         pizza clasica   Fast_Food, Pizzeria,
# 11            El Rincón de San Francisco               Mexican,
# 12                  Restaurant Orizatlan               Mexican,
# 13                  Restaurante Tiberius              Pizzeria,
# 14                  la Estrella de Dimas
# 15                       puesto de tacos               Mexican,
# 16                         Little Cesarz              Pizzeria,
# 17          Restaurant Familiar El Chino            Vietnamese,
# 18                             shi ro ie              Japanese,
# 19                       Cabana Huasteca               Mexican,
# 20                          don burguers
# 21                    tacos los volcanes              American,
# 22                               Sirlone         International,
# 23                  Restaurant Orizatlan               Mexican,
# 24                                  vips               Mexican,
# 25      El Herradero Restaurante and Bar                   Bar,
# 26                                  vips               Mexican,
# 27                             emilianos       Bar_Pub_Brewery,
# 28                             Paniroles               Italian,
# 29                 la perica hamburguesa               Italian,
# ..                                   ...                     ...
# 108      Restaurante la Estrella de Dima
# 109                     El Oceano Dorado               Mexican,
# 110        Carreton de Flautas y Migadas               Mexican,
# 111                 La Estrella de Dimas               Mexican,
# 112               Restaurante la Cantina  Bar, Bar_Pub_Brewery,
# 113                la perica hamburguesa               Italian,
# 114                          rockabilly                    Bar,
# 115                            shi ro ie              Japanese,
# 116        Carreton de Flautas y Migadas               Mexican,
# 117     El Herradero Restaurante and Bar                   Bar,
# 118         Restaurant Familiar El Chino            Vietnamese,
# 119                              Sirlone         International,
# 120                      Cabana Huasteca               Mexican,
# 121        Carreton de Flautas y Migadas               Mexican,
# 122                     El Oceano Dorado               Mexican,
# 123               Restaurante la Cantina  Bar, Bar_Pub_Brewery,
# 124                          El cotorreo       Family, Mexican,
# 125              Restaurante El Reyecito             Fast_Food,
# 126                          el pueblito               Mexican,
# 127                    Gordas de morales               Mexican,
# 128               Restaurante la Cantina  Bar, Bar_Pub_Brewery,
# 129                 cafe punta del cielo             Cafeteria,
# 130  Cenaduria El RincÃ³n de Tlaquepaque               Mexican,
# 131        Carreton de Flautas y Migadas               Mexican,
# 132                    Cafeteria cenidet             Cafeteria,
# 133                            Paniroles               Italian,
# 134                              Sirlone         International,
# 135                          La Virreina               Mexican,
# 136                    Cafeteria cenidet             Cafeteria,
# 137                              Sirlone         International,
#
#                                         Rec5              Rec5_Cuisines
# 0                                       vips                  Mexican,
# 1                                El cotorreo          Family, Mexican,
# 2                                el pueblito                  Mexican,
# 3        Cenaduria El RincÃ³n de Tlaquepaque                  Mexican,
# 4    la Cochinita Pibil Restaurante Yucateco                  Mexican,
# 5                               la parroquia         Breakfast-Brunch,
# 6                                       Vips
# 7                           El Oceano Dorado                  Mexican,
# 8                      Restaurant la Chalita
# 9                 El Rincón de San Francisco                  Mexican,
# 10                           puesto de tacos                  Mexican,
# 11                           Cabana Huasteca                  Mexican,
# 12                          El Oceano Dorado                  Mexican,
# 13                             Little Cesarz                 Pizzeria,
# 14                                      vips                  Mexican,
# 15             Carreton de Flautas y Migadas                  Mexican,
# 16                El Rincón de San Francisco                  Mexican,
# 17                               rockabilly                       Bar,
# 18          Restaurant El Muladar de Calzada
# 19                El Rincón de San Francisco                  Mexican,
# 20                             carnitas_mata                  Mexican,
# 21                           Cabana Huasteca                  Mexican,
# 22                    La Cantina Restaurante     Bar, Bar_Pub_Brewery,
# 23                                    Mikasa                 Japanese,
# 24                           Cabana Huasteca                  Mexican,
# 25      Restaurant Bar Hacienda los Martinez                      Bar,
# 26                El Rincón de San Francisco                  Mexican,
# 27       Cenaduria El RincÃ³n de Tlaquepaque                  Mexican,
# 28       Cenaduria El RincÃ³n de Tlaquepaque                  Mexican,
# 29                      Sanborns Casa Piedra
# ..                                       ...                        ...
# 108                             don burguers
# 109     Restaurant Bar Hacienda los Martinez                      Bar,
# 110                    Restaurante Versalles
# 111                            Little Cesarz                 Pizzeria,
# 112                             tortas hawai                Fast_Food,
# 113                          Cabana Huasteca                  Mexican,
# 114                                     vips                  Mexican,
# 115       Cafeteria y Restaurant El Pacifico  Cafeteria, Contemporary,
# 116                        Gordas de morales                  Mexican,
# 117       Cafeteria y Restaurant El Pacifico  Cafeteria, Contemporary,
# 118               El Rincón de San Francisco                  Mexican,
# 119                                     Vips
# 120                          puesto de tacos                  Mexican,
# 121               El Rincon de San Francisco                  Mexican,
# 122                     La Estrella de Dimas                  Mexican,
# 123                                      KFC           American, Game,
# 124                             tortas hawai                Fast_Food,
# 125            Carreton de Flautas y Migadas                  Mexican,
# 126                   Restaurante la Cantina     Bar, Bar_Pub_Brewery,
# 127                                     vips                  Mexican,
# 128                     Restaurant Orizatlan                  Mexican,
# 129                                     vips                  Mexican,
# 130                     Restaurant Orizatlan                  Mexican,
# 131                     Restaurant Orizatlan                  Mexican,
# 132                    la perica hamburguesa                  Italian,
# 133                                  Chaires        Bakery, Cafeteria,
# 134                     cafe punta del cielo                Cafeteria,
# 135                               palomo tec                  Mexican,
# 136                         El Oceano Dorado                  Mexican,
# 137                     cafe punta del cielo                Cafeteria,
#
# [138 rows x 11 columns]

# %%
len(df['Rec5'].value_counts().index.tolist())
# Out:
# 55

# %%
np.array(user_profile[user_profile['userID']=='U1093'])
# Out:
# array([['U1093', 18.871654, -99.183251, 'true', 'casual drinker',
#         'no preference', 'family', 'car owner', 'single', 'independent',
#         1990, 'variety', 'thrifty-protector', 'Catholic', 'student',
#         'blue', 80, 'medium', 1.67, 'Japanese ',
#         'American_Express VISA ']], dtype=object)

# %%
#normalized context matrix
best_val_loss = 1000.0
best_val_accuracy = 0.0
for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(4,5):  
        fusion = fusion_arr[f]
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = MatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1], n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            #best_train_loss = 1000.0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_orig)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_orig[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_orig.shape[1])))
                first = (contexts_norm[batch,:].toarray())*fusion
        
                #contexts = Variable(torch.FloatTensor(contexts_full[batch,:].toarray()))
                contexts = Variable(torch.FloatTensor(first))
        
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_norm)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_orig.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path)
        
            val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_norm,fusion, batch_size, save_path)
        #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full, fusion, batch_size, save_path)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                #checkpoint_model(val_loss, model, save_path_val)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                checkpoint_model(val_loss, model, save_path_val)
                print ('New Best Val Accuracy: ' + str(best_val_accuracy) + ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 1.0
# Epoch: 0
# train_loss: 1.5953203324064973
# accuracy:0.4088050314465409
# checkpoint model with train loss: 1.5953203324064973
# val_loss
# model_state_dict
# val loss: 1.6092428733083792
# val accuracy: 0.41697416974169743
# checkpointing_model with val loss: 1.6092428733083792
# New Best Val Accuracy: 0.41697416974169743 with fusion: 1.0 and factor :2
# Epoch: 1
# train_loss: 1.6419990740404462
# accuracy:0.40723270440251574
# val_loss
# model_state_dict
# val loss: 1.6005873782247861
# val accuracy: 0.4280442804428044
# checkpointing_model with val loss: 1.6005873782247861
# New Best Val Accuracy: 0.4280442804428044 with fusion: 1.0 and factor :2
# Epoch: 2
# train_loss: 1.6278343387715004
# accuracy:0.389937106918239
# val_loss
# model_state_dict
# val loss: 1.6368432006261795
# val accuracy: 0.4095940959409594
# Epoch: 3
# train_loss: 1.6197427045116453
# accuracy:0.4056603773584906
# val_loss
# model_state_dict
# val loss: 1.600682188265247
# val accuracy: 0.3948339483394834
# Epoch: 4
# train_loss: 1.6222164820805405
# accuracy:0.3915094339622642
# val_loss
# model_state_dict
# val loss: 1.6021485921105614
# val accuracy: 0.42435424354243545

# %%
rest_profile[rest_profile['name']== 'El Rincon de San Francisco']
# Out:
#     placeID  latitude  longitude  \
# 34   135025  22.14955 -100.97797
#
#                                        the_geom_meter  \
# 34  0101000020957F0000C7080D105C4858C108B4006AB4A3...
#
#                           name          address             city state  \
# 34  El Rincon de San Francisco  1a. de Lozada 1  San Luis Potosi   SLP
#
#    country fax   ...       accessibility   price url Rambience franchise  \
# 34  Mexico   ?   ...    no_accessibility  medium   ?  familiar         f
#
#       area other_services   Cuisine  \
# 34  closed           none  Mexican
#
#                                             Payment Parking
# 34  cash VISA MasterCard-Eurocard American_Express    none
#
# [1 rows x 24 columns]

# %%
mean = np.mean(interactions_train_orig)
save_path_b = './project_models/bmodel.ckpt'
save_path_val_b = './project_models/bmodelv.ckpt'

# %%
#original ratings
best_val_loss = 1000.0
best_val_accuracy = 0.0
for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(len(fusion_arr)):  
        fusion = fusion_arr[f]
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = BiasedMatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1],mean, n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            #best_train_loss = 1000.0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_orig)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_orig[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_orig.shape[1])))
                first = (contexts_full[batch,:].toarray())*fusion
        
                #contexts = Variable(torch.FloatTensor(contexts_full[batch,:].toarray()))
                contexts = Variable(torch.FloatTensor(first))
        
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_orig.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path_b)
        
            val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full,fusion, batch_size, save_path_b)
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full, fusion, batch_size, save_path)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val_b)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                print ('New Best Val Accuracy: ' + str(best_val_accuracy) + ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 0.0
# Epoch: 0
# train_loss: 2.0344426130126108
# accuracy:0.3757861635220126
# checkpoint model with train loss: 2.0344426130126108
# val_loss
# model_state_dict
# val loss: 2.0207340815861814
# val accuracy: 0.36900369003690037
# checkpointing_model with val loss: 2.0207340815861814
# New Best Val Accuracy: 0.36900369003690037 with fusion: 0.0 and factor :2
# Epoch: 1
# train_loss: 2.0378799170777215
# accuracy:0.35691823899371067
# val_loss
# model_state_dict
# val loss: 2.0235122278762265
# val accuracy: 0.3726937269372694
# New Best Val Accuracy: 0.3726937269372694 with fusion: 0.0 and factor :2
# Epoch: 2
# train_loss: 2.0514629602529597
# accuracy:0.36792452830188677
# val_loss
# model_state_dict
# val loss: 2.026163034851297
# val accuracy: 0.4280442804428044
# New Best Val Accuracy: 0.4280442804428044 with fusion: 0.0 and factor :2
# Epoch: 3
# train_loss: 2.037140381244963
# accuracy:0.3757861635220126
# val_loss
# model_state_dict
# val loss: 2.020523810692569
# val accuracy: 0.4095940959409594
# checkpointing_model with val loss: 2.020523810692569
# Epoch: 4
# train_loss: 2.037726015627366
# accuracy:0.38836477987421386
# val_loss
# model_state_dict
# val loss: 2.0353896296583276
# val accuracy: 0.4022140221402214
# FUSION: 0.25
# Epoch: 0
# train_loss: 2.1257762935056377
# accuracy:0.3553459119496855
# checkpoint model with train loss: 2.1257762935056377
# val_loss
# model_state_dict
# val loss: 2.129270543630152
# val accuracy: 0.3726937269372694
# Epoch: 1
# train_loss: 2.1574416093683655
# accuracy:0.389937106918239
# val_loss
# model_state_dict
# val loss: 2.1318539101166887
# val accuracy: 0.3247232472324723
# Epoch: 2
# train_loss: 2.1404276252374843
# accuracy:0.3694968553459119
# val_loss
# model_state_dict
# val loss: 2.135072350961601
# val accuracy: 0.3763837638376384
# Epoch: 3
# train_loss: 2.1243545040889775
# accuracy:0.35062893081761004
# checkpoint model with train loss: 2.1243545040889775
# val_loss
# model_state_dict
# val loss: 2.1282660754263563
# val accuracy: 0.39114391143911437
# Epoch: 4
# train_loss: 2.1371859208337227
# accuracy:0.33490566037735847
# val_loss
# model_state_dict
# val loss: 2.129870591583735
# val accuracy: 0.3505535055350554
# FUSION: 0.5
# Epoch: 0
# train_loss: 2.9405816705502366
# accuracy:0.38522012578616355
# checkpoint model with train loss: 2.9405816705502366
# val_loss
# model_state_dict
# val loss: 2.9629230225893957
# val accuracy: 0.3800738007380074
# Epoch: 1
# train_loss: 2.9346075576277726
# accuracy:0.36163522012578614
# checkpoint model with train loss: 2.9346075576277726
# val_loss
# model_state_dict
# val loss: 2.9456599121808655
# val accuracy: 0.4132841328413284
# Epoch: 2
# train_loss: 2.9243552159348467
# accuracy:0.37735849056603776
# checkpoint model with train loss: 2.9243552159348467
# val_loss
# model_state_dict
# val loss: 2.963999082440803
# val accuracy: 0.3505535055350554
# Epoch: 3
# train_loss: 2.919573790784346
# accuracy:0.39308176100628933
# checkpoint model with train loss: 2.919573790784346
# val_loss
# model_state_dict
# val loss: 2.936288562008423
# val accuracy: 0.3985239852398524
# Epoch: 4
# train_loss: 2.961514897480895
# accuracy:0.38836477987421386
# val_loss
# model_state_dict
# val loss: 2.9605754846810437
# val accuracy: 0.42066420664206644
# FUSION: 0.75
# Epoch: 0
# train_loss: 3.5169897309533966
# accuracy:0.39622641509433965
# checkpoint model with train loss: 3.5169897309533966
# val_loss
# model_state_dict
# val loss: 3.519535451204968
# val accuracy: 0.44280442804428044
# New Best Val Accuracy: 0.44280442804428044 with fusion: 0.75 and factor :2
# Epoch: 1
# train_loss: 3.4882614031526984
# accuracy:0.4386792452830189
# checkpoint model with train loss: 3.4882614031526984
# val_loss
# model_state_dict
# val loss: 3.541015891847937
# val accuracy: 0.47601476014760147
# New Best Val Accuracy: 0.47601476014760147 with fusion: 0.75 and factor :2
# Epoch: 2
# train_loss: 3.481144730698987
# accuracy:0.38522012578616355
# checkpoint model with train loss: 3.481144730698987
# val_loss
# model_state_dict
# val loss: 3.5169479803840025
# val accuracy: 0.45387453874538747
# Epoch: 3
# train_loss: 3.4867428041561075
# accuracy:0.42138364779874216
# val_loss
# model_state_dict
# val loss: 3.5282300555946158
# val accuracy: 0.3948339483394834
# Epoch: 4
# train_loss: 3.4858038940566938
# accuracy:0.4276729559748428
# val_loss
# model_state_dict
# val loss: 3.5481554581437496
# val accuracy: 0.45387453874538747
# FUSION: 1.0
# Epoch: 0
# train_loss: 4.469399917393803
# accuracy:0.37264150943396224
# checkpoint model with train loss: 4.469399917393803
# val_loss
# model_state_dict
# val loss: 4.443929446316185
# val accuracy: 0.36531365313653136
# Epoch: 1
# train_loss: 4.481002249222907
# accuracy:0.40723270440251574
# val_loss
# model_state_dict
# val loss: 4.472556682671444
# val accuracy: 0.4132841328413284
# Epoch: 2
# train_loss: 4.467511048093067
# accuracy:0.42452830188679247
# checkpoint model with train loss: 4.467511048093067
# val_loss
# model_state_dict
# val loss: 4.478977976166556
# val accuracy: 0.4022140221402214
# Epoch: 3
# train_loss: 4.445112384877318
# accuracy:0.4119496855345912
# checkpoint model with train loss: 4.445112384877318
# val_loss
# model_state_dict
# val loss: 4.436334860993094
# val accuracy: 0.39114391143911437
# Epoch: 4
# train_loss: 4.4260395006367625
# accuracy:0.4056603773584906
# checkpoint model with train loss: 4.4260395006367625
# val_loss
# model_state_dict
# val loss: 4.506238125914599
# val accuracy: 0.3726937269372694

# %%
recs = generate_predictions(model, contexts_full, interactions_full_orig, save_path_val)
results = give_top5_cuisines(recs, rest_profile, rest_cuisine, user_list, item_list)
# Out:
# val_loss
# model_state_dict

# %%
df = pd.DataFrame(results,columns = col_names)

# %%
df
# Out:
#       User                                  Rec1  \
# 0    U1077                      El Oceano Dorado
# 1    U1068            El Rincon de San Francisco
# 2    U1067                                  vips
# 3    U1103                      El Oceano Dorado
# 4    U1107                  El Mundo de la Pasta
# 5    U1044                      El Oceano Dorado
# 6    U1070                           La Virreina
# 7    U1031            El Rincon de San Francisco
# 8    U1082                      El Oceano Dorado
# 9    U1023            El Rincon de San Francisco
# 10   U1060                           el pueblito
# 11   U1015                     Gordas de morales
# 12   U1123                    Gorditas Dona Tota
# 13   U1021           Mcdonalds Parque Tangamanga
# 14   U1026            El Rincon de San Francisco
# 15   U1083                      Restaurant Teely
# 16   U1108                                  vips
# 17   U1012                               Sirlone
# 18   U1093                           La Virreina
# 19   U1030                           La Virreina
# 20   U1066                      El Oceano Dorado
# 21   U1127                           rockabilly
# 22   U1017                           La Virreina
# 23   U1100                             Luna Cafe
# 24   U1133                      El Oceano Dorado
# 25   U1118  Restaurant Bar Hacienda los Martinez
# 26   U1072                           La Virreina
# 27   U1080                          Cafe Chaires
# 28   U1063   Cenaduria El RincÃ³n de Tlaquepaque
# 29   U1074                             Luna Cafe
# ..     ...                                   ...
# 108  U1091                                  VIPS
# 109  U1027                     Gordas de morales
# 110  U1029                           La Virreina
# 111  U1086                         Little Cesarz
# 112  U1137                             Luna Cafe
# 113  U1090                         Unicols Pizza
# 114  U1061                    Mariscos Tia Licha
# 115  U1041                  La Estrella de Dimas
# 116  U1059   Cenaduria El RincÃ³n de Tlaquepaque
# 117  U1112                      El Oceano Dorado
# 118  U1057                     Gordas de morales
# 119  U1025                                  vips
# 120  U1097                      El Oceano Dorado
# 121  U1006                     Gordas de morales
# 122  U1131                     Gordas de morales
# 123  U1073                    tacos los volcanes
# 124  U1058                             Luna Cafe
# 125  U1002                          Cafe Chaires
# 126  U1096                           La Virreina
# 127  U1136                      El Oceano Dorado
# 128  U1010            El Rincon de San Francisco
# 129  U1028                                  vips
# 130  U1050            El Rincon de San Francisco
# 131  U1129                             Luna Cafe
# 132  U1087                             Paniroles
# 133  U1065                          Cafe Chaires
# 134  U1039                          Cafe Chaires
# 135  U1130                               Log Yin
# 136  U1043            El Rincon de San Francisco
# 137  U1011                     Gordas de morales
#
#                          Rec1_Cuisines                                 Rec2  \
# 0                            Mexican,                  La Estrella de Dimas
# 1                            Mexican,                     Gordas de morales
# 2                            Mexican,                       puesto de tacos
# 3                            Mexican,                     Gordas de morales
# 4                            Italian,      Restaurante y Pescaderia Tampico
# 5                            Mexican,                     Gordas de morales
# 6                            Mexican,                  Restaurant Orizatlan
# 7                            Mexican,                  tacos de la estacion
# 8                            Mexican,                     Gordas de morales
# 9                            Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 10                           Mexican,                  Restaurant Orizatlan
# 11                           Mexican,                                  vips
# 12                           Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 13                Burgers, Fast_Food,                                  vips
# 14                           Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 15                                                       Gorditas Dona Tota
# 16                           Mexican,                    tacos los volcanes
# 17                     International,                             Luna Cafe
# 18                           Mexican,                      Restaurant Teely
# 19                           Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 20                           Mexican,                           rockabilly
# 21                               Bar,                             Paniroles
# 22                           Mexican,          Restaurant Familiar El Chino
# 23                    Bar, Cafeteria,            El Rincon de San Francisco
# 24                           Mexican,                  La Estrella de Dimas
# 25                               Bar,    Cafeteria y Restaurant El Pacifico
# 26                           Mexican,                          Cafe Chaires
# 27                         Cafeteria,                           La Virreina
# 28                           Mexican,                     Gordas de morales
# 29                    Bar, Cafeteria,                  La Posada del Virrey
# ..                                 ...                                  ...
# 108                         American,                           La Virreina
# 109                          Mexican,                       Rincon del Bife
# 110                          Mexican,                      El Oceano Dorado
# 111                         Pizzeria,                  La Estrella de Dimas
# 112                   Bar, Cafeteria,                  tacos de la estacion
# 113                          Italian,                        Restaurante 75
# 114                           Family,                                  vips
# 115                          Mexican,                Restaurante la Cantina
# 116                          Mexican,            El Rincon de San Francisco
# 117                          Mexican,            El Rincón de San Francisco
# 118                          Mexican,            El Rincon de San Francisco
# 119                          Mexican,                     Gordas de morales
# 120                          Mexican,                           el pueblito
# 121                          Mexican,                      El Oceano Dorado
# 122                          Mexican,            El Rincon de San Francisco
# 123                         American,                              crudalia
# 124                   Bar, Cafeteria,                               El Club
# 125                        Cafeteria,   Cenaduria El RincÃ³n de Tlaquepaque
# 126                          Mexican,                      El Oceano Dorado
# 127                          Mexican,                         carnitas_mata
# 128                          Mexican,                     Gordas de morales
# 129                          Mexican,                      El Oceano Dorado
# 130                          Mexican,                         pizza clasica
# 131                   Bar, Cafeteria,                  tacos de la estacion
# 132                          Italian,                          Cafe Chaires
# 133                        Cafeteria,                           La Virreina
# 134                        Cafeteria,                             Paniroles
# 135  Mexican, Mediterranean, Burgers,            El Rincon de San Francisco
# 136                          Mexican,                     Gordas de morales
# 137                          Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
#
#                  Rec2_Cuisines                                 Rec3  \
# 0                    Mexican,                           La Virreina
# 1                    Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 2                    Mexican,           Mcdonalds Parque Tangamanga
# 3                    Mexican,                  La Estrella de Dimas
# 4                    Seafood,                       puesto de tacos
# 5                    Mexican,                                  vips
# 6                    Mexican,                           el pueblito
# 7                    Mexican,                               Log Yin
# 8                    Mexican,                                  vips
# 9                    Mexican,                               Log Yin
# 10                   Mexican,                           La Virreina
# 11                   Mexican,                      El Oceano Dorado
# 12                   Mexican,                          Cafe Chaires
# 13                   Mexican,                              Carls Jr
# 14                   Mexican,                       Cabana Huasteca
# 15                   Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 16                  American,                            Sushi Itto
# 17            Bar, Cafeteria,    Cafeteria y Restaurant El Pacifico
# 18                                           Restaurante la Cantina
# 19                   Mexican,                             Paniroles
# 20                       Bar,                  La Estrella de Dimas
# 21                   Italian,                     Gordas de morales
# 22                Vietnamese,                Restaurante la Cantina
# 23                   Mexican,                     Gordas de morales
# 24                   Mexican,                                  vips
# 25   Cafeteria, Contemporary,                      El Oceano Dorado
# 26                 Cafeteria,                  La Estrella de Dimas
# 27                   Mexican,                      El Oceano Dorado
# 28                   Mexican,            El Rincon de San Francisco
# 29             International,                    Mariscos Tia Licha
# ..                         ...                                  ...
# 108                  Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 109                                          Restaurante la Cantina
# 110                  Mexican,            El Rincón de San Francisco
# 111                  Mexican,                      El Oceano Dorado
# 112                  Mexican,    tacos de barbacoa enfrente del Tec
# 113                                     Mcdonalds Parque Tangamanga
# 114                  Mexican,                      El Oceano Dorado
# 115     Bar, Bar_Pub_Brewery,                           La Virreina
# 116                  Mexican,                     Gordas de morales
# 117                  Mexican,                           La Virreina
# 118                  Mexican,            El Rincón de San Francisco
# 119                  Mexican,            El Rincon de San Francisco
# 120                  Mexican,                       puesto de tacos
# 121                  Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 122                  Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 123                      Bar,                Hamburguesas La perica
# 124                                               Gordas de morales
# 125                  Mexican,                    Gorditas Dona Tota
# 126                  Mexican,                  La Estrella de Dimas
# 127                  Mexican,                       puesto de tacos
# 128                  Mexican,                         pizza clasica
# 129                  Mexican,                     Gordas de morales
# 130      Fast_Food, Pizzeria,                                  vips
# 131                  Mexican,           Mcdonalds Parque Tangamanga
# 132                Cafeteria,                           rockabilly
# 133                  Mexican,   Cenaduria El RincÃ³n de Tlaquepaque
# 134                  Italian,                    Gorditas Dona Tota
# 135                  Mexican,                  tacos de la estacion
# 136                  Mexican,                         pizza clasica
# 137                  Mexican,            El Rincon de San Francisco
#
#                          Rec3_Cuisines  \
# 0                            Mexican,
# 1                            Mexican,
# 2                 Burgers, Fast_Food,
# 3                            Mexican,
# 4                            Mexican,
# 5                            Mexican,
# 6                            Mexican,
# 7    Mexican, Mediterranean, Burgers,
# 8                            Mexican,
# 9    Mexican, Mediterranean, Burgers,
# 10                           Mexican,
# 11                           Mexican,
# 12                         Cafeteria,
# 13                           Burgers,
# 14                           Mexican,
# 15                           Mexican,
# 16                          Japanese,
# 17           Cafeteria, Contemporary,
# 18              Bar, Bar_Pub_Brewery,
# 19                           Italian,
# 20                           Mexican,
# 21                           Mexican,
# 22              Bar, Bar_Pub_Brewery,
# 23                           Mexican,
# 24                           Mexican,
# 25                           Mexican,
# 26                           Mexican,
# 27                           Mexican,
# 28                           Mexican,
# 29                            Family,
# ..                                 ...
# 108                          Mexican,
# 109             Bar, Bar_Pub_Brewery,
# 110                          Mexican,
# 111                          Mexican,
# 112                          Mexican,
# 113               Burgers, Fast_Food,
# 114                          Mexican,
# 115                          Mexican,
# 116                          Mexican,
# 117                          Mexican,
# 118                          Mexican,
# 119                          Mexican,
# 120                          Mexican,
# 121                          Mexican,
# 122                          Mexican,
# 123                          Mexican,
# 124                          Mexican,
# 125                          Mexican,
# 126                          Mexican,
# 127                          Mexican,
# 128              Fast_Food, Pizzeria,
# 129                          Mexican,
# 130                          Mexican,
# 131               Burgers, Fast_Food,
# 132                              Bar,
# 133                          Mexican,
# 134                          Mexican,
# 135                          Mexican,
# 136              Fast_Food, Pizzeria,
# 137                          Mexican,
#
#                                                   Rec4  \
# 0                                 Restaurant Orizatlan
# 1                                              Log Yin
# 2                                            Luna Cafe
# 3                  Cenaduria El RincÃ³n de Tlaquepaque
# 4                               Restaurante Bar Fu-hao
# 5                           El Rincón de San Francisco
# 6                                     El Oceano Dorado
# 7                  Cenaduria El RincÃ³n de Tlaquepaque
# 8                                        carnitas_mata
# 9                                    Gordas de morales
# 10                                    El Oceano Dorado
# 11                                  Gorditas Dona Tota
# 12                                         La Virreina
# 13                               Restaurant Wu Zhuo Yi
# 14                                   Gordas de morales
# 15                                           Paniroles
# 16                                           Luna Cafe
# 17                                              Mikasa
# 18                    El Herradero Restaurante and Bar
# 19                                     Cabana Huasteca
# 20                                   Gordas de morales
# 21                 Cenaduria El RincÃ³n de Tlaquepaque
# 22                                Restaurant Orizatlan
# 23                                       pizza clasica
# 24                                       Little Cesarz
# 25                    El Herradero Restaurante and Bar
# 26                                   Chilis Cuernavaca
# 27                                cafe punta del cielo
# 28                                         La Virreina
# 29                                       pizza clasica
# ..                                                 ...
# 108                                 Gorditas Dona Tota
# 109  Restaurant and Bar and Clothesline Carlos N Ch...
# 110                                   Restaurant Teely
# 111                                        La Virreina
# 112                                               vips
# 113                                    puesto de tacos
# 114                                 Gorditas Dona Tota
# 115                                   El Oceano Dorado
# 116                                      pizza clasica
# 117                                        el pueblito
# 118                                    Rincon del Bife
# 119                                 Gorditas Dona Tota
# 120                               La Estrella de Dimas
# 121                         El Rincon de San Francisco
# 122                                               vips
# 123                                        rockabilly
# 124                                         Sushi Itto
# 125                                Gorditas Doa Gloria
# 126                               Restaurant Orizatlan
# 127                                  Gordas de morales
# 128                Cenaduria El RincÃ³n de Tlaquepaque
# 129                                 Gorditas Dona Tota
# 130                                          Luna Cafe
# 131                                               vips
# 132                        Restaurant Oriental Express
# 133                                    Cabana Huasteca
# 134                                   Restaurant Teely
# 135                Cenaduria El RincÃ³n de Tlaquepaque
# 136                                          Paniroles
# 137                                 Gorditas Dona Tota
#
#                          Rec4_Cuisines  \
# 0                            Mexican,
# 1    Mexican, Mediterranean, Burgers,
# 2                     Bar, Cafeteria,
# 3                            Mexican,
# 4                                Bar,
# 5                            Mexican,
# 6                            Mexican,
# 7                            Mexican,
# 8                            Mexican,
# 9                            Mexican,
# 10                           Mexican,
# 11                           Mexican,
# 12                           Mexican,
# 13                           Chinese,
# 14                           Mexican,
# 15                           Italian,
# 16                    Bar, Cafeteria,
# 17                          Japanese,
# 18                               Bar,
# 19                           Mexican,
# 20                           Mexican,
# 21                           Mexican,
# 22                           Mexican,
# 23               Fast_Food, Pizzeria,
# 24                          Pizzeria,
# 25                               Bar,
# 26
# 27                         Cafeteria,
# 28                           Mexican,
# 29               Fast_Food, Pizzeria,
# ..                                 ...
# 108                          Mexican,
# 109             Bar, Bar_Pub_Brewery,
# 110
# 111                          Mexican,
# 112                          Mexican,
# 113                          Mexican,
# 114                          Mexican,
# 115                          Mexican,
# 116              Fast_Food, Pizzeria,
# 117                          Mexican,
# 118
# 119                          Mexican,
# 120                          Mexican,
# 121                          Mexican,
# 122                          Mexican,
# 123                              Bar,
# 124                         Japanese,
# 125                          Mexican,
# 126                          Mexican,
# 127                          Mexican,
# 128                          Mexican,
# 129                          Mexican,
# 130                   Bar, Cafeteria,
# 131                          Mexican,
# 132                          Chinese,
# 133                          Mexican,
# 134
# 135                          Mexican,
# 136                          Italian,
# 137                          Mexican,
#
#                                                   Rec5  \
# 0                               Restaurante la Cantina
# 1                                            Luna Cafe
# 2                                           Sushi Itto
# 3                           El Rincon de San Francisco
# 4                                   tacos los volcanes
# 5                           El Rincon de San Francisco
# 6                                    Chilis Cuernavaca
# 7                                    Gordas de morales
# 8                   Cafeteria y Restaurant El Pacifico
# 9                                        pizza clasica
# 10                  Cafeteria y Restaurant El Pacifico
# 11                                           Luna Cafe
# 12                                     Cabana Huasteca
# 13                                       pizza clasica
# 14                              Tortas Locas Hipocampo
# 15                                     Rincon del Bife
# 16                                             El Club
# 17                Restaurant Bar Hacienda los Martinez
# 18                          El Rincón de San Francisco
# 19                                        Cafe Chaires
# 20                                                vips
# 21                                  Gorditas Dona Tota
# 22                          El Rincón de San Francisco
# 23                                             El Club
# 24                                         el pueblito
# 25                              Restaurante la Cantina
# 26                                    El Oceano Dorado
# 27   Restaurant and Bar and Clothesline Carlos N Ch...
# 28                                     Cabana Huasteca
# 29                                             El Club
# ..                                                 ...
# 108                                Gorditas Doa Gloria
# 109                                        El cotorreo
# 110                               Restaurant Orizatlan
# 111                                  Chilis Cuernavaca
# 112                             Hamburguesas La perica
# 113                              Restaurant la Chalita
# 114                                         Sushi Itto
# 115                                       la parroquia
# 116                                Gorditas Doa Gloria
# 117                               Restaurant Orizatlan
# 118                       Restaurant Familiar El Chino
# 119                                          Luna Cafe
# 120                               Restaurant Orizatlan
# 121                         El Rincón de San Francisco
# 122                                      pizza clasica
# 123                                   El Oceano Dorado
# 124                 Cafeteria y Restaurant El Pacifico
# 125                                               VIPS
# 126                                        el pueblito
# 127                                               vips
# 128                                               vips
# 129                                        el pueblito
# 130                               tacos de la estacion
# 131                                            El Club
# 132                                        La Virreina
# 133                                          Paniroles
# 134                                               VIPS
# 135                                  Gordas de morales
# 136                Cenaduria El RincÃ³n de Tlaquepaque
# 137                                    Cabana Huasteca
#
#                  Rec5_Cuisines
# 0       Bar, Bar_Pub_Brewery,
# 1             Bar, Cafeteria,
# 2                   Japanese,
# 3                    Mexican,
# 4                   American,
# 5                    Mexican,
# 6
# 7                    Mexican,
# 8    Cafeteria, Contemporary,
# 9        Fast_Food, Pizzeria,
# 10   Cafeteria, Contemporary,
# 11            Bar, Cafeteria,
# 12                   Mexican,
# 13       Fast_Food, Pizzeria,
# 14                 Fast_Food,
# 15
# 16
# 17                       Bar,
# 18                   Mexican,
# 19                 Cafeteria,
# 20                   Mexican,
# 21                   Mexican,
# 22                   Mexican,
# 23
# 24                   Mexican,
# 25      Bar, Bar_Pub_Brewery,
# 26                   Mexican,
# 27      Bar, Bar_Pub_Brewery,
# 28                   Mexican,
# 29
# ..                         ...
# 108                  Mexican,
# 109          Family, Mexican,
# 110                  Mexican,
# 111
# 112                  Mexican,
# 113
# 114                 Japanese,
# 115         Breakfast-Brunch,
# 116                  Mexican,
# 117                  Mexican,
# 118               Vietnamese,
# 119           Bar, Cafeteria,
# 120                  Mexican,
# 121                  Mexican,
# 122      Fast_Food, Pizzeria,
# 123                  Mexican,
# 124  Cafeteria, Contemporary,
# 125                 American,
# 126                  Mexican,
# 127                  Mexican,
# 128                  Mexican,
# 129                  Mexican,
# 130                  Mexican,
# 131
# 132                  Mexican,
# 133                  Italian,
# 134                 American,
# 135                  Mexican,
# 136                  Mexican,
# 137                  Mexican,
#
# [138 rows x 11 columns]

# %%
give_number_of_contexts(recs, contexts_full, 'U1093', user_list,item_list)
# Out:
# [18]
# [3.0, 6.0, 3.0, 7.0, 6.0]

# %%
give_number_of_contexts(recs, contexts_full, 'U1077', user_list,item_list)
# Out:
# [0]
# [7.0, 6.0, 8.0, 5.0, 9.0]

# %%
len(df['Rec5'].value_counts().index.tolist())
# Out:
# 51

# %%
best_val_loss = 1000.0
best_val_accuracy = 0.0
for x in range(1):
    print ('Factor ' + str(factors[x]))
    for f in range(len(fusion_arr)):  
        fusion = fusion_arr[f]
        print ('FUSION: ' + str(fusion))
        best_train_loss = 1000.0
        #accur = 0
        model = BiasedMatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1], mean, n_factors=factors[x])
        loss_func = torch.nn.MSELoss()
        reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
        for i in range(5):
            print ("Epoch: " + str(i))
            running_loss = 0.0
            accur = 0
            #best_train_loss = 1000.0
            for m, batch in enumerate(get_batch(batch_size, interactions_train_orig)):
                reg_loss_func.zero_grad()
                interactions = Variable(torch.FloatTensor(interactions_train_orig[batch,:].toarray()))
                rows = Variable(torch.LongTensor(batch))
                cols = Variable(torch.LongTensor(np.arange(interactions_train_orig.shape[1])))
                first = (contexts_norm[batch,:].toarray())*fusion
        
                #contexts = Variable(torch.FloatTensor(contexts_full[batch,:].toarray()))
                contexts = Variable(torch.FloatTensor(first))
        
                predictions = model(rows, cols, contexts)
        
                loss = loss_func(predictions, interactions)
                running_loss += np.sqrt(loss.data[0])*batch_size
                
                #correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
                correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_norm)
                accur = accur + correct
                
                loss.backward()
            reg_loss_func.step()
    
            epoch_loss = running_loss/interactions_train_orig.shape[0]
            print ('train_loss: ' + str(epoch_loss))
            
            print ('accuracy:' + str(accur/len(checks[0])))
            
            if epoch_loss < best_train_loss:
                best_train_loss = epoch_loss
                print ('checkpoint model with train loss: ' + str(best_train_loss))
                checkpoint_model(epoch_loss, model, save_path_b)
        
            val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_norm,fusion, batch_size, save_path_b)
            #val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full, fusion, batch_size, save_path)
            print ('val loss: ' + str(val_loss))
            val_percent = val_accuracy/len(checks_v[0])
            print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
        
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                print ('checkpointing_model with val loss: ' + str(best_val_loss))
                checkpoint_model(val_loss, model, save_path_val_b)
            if val_percent > best_val_accuracy:
                best_val_accuracy = val_percent
                print ('New Best Val Accuracy: ' + str(best_val_accuracy) + ' with fusion: ' + str(fusion) + ' and factor :' + str(factors[x]))
# Out:
# Factor 2
# FUSION: 0.0
# Epoch: 0
# train_loss: 1.9315029758506124
# accuracy:0.3789308176100629
# checkpoint model with train loss: 1.9315029758506124
# val_loss
# model_state_dict
# val loss: 1.9252421126496666
# val accuracy: 0.34317343173431736
# checkpointing_model with val loss: 1.9252421126496666
# New Best Val Accuracy: 0.34317343173431736 with fusion: 0.0 and factor :2
# Epoch: 1
# train_loss: 1.9473183091662358
# accuracy:0.389937106918239
# val_loss
# model_state_dict
# val loss: 1.8907640380906259
# val accuracy: 0.3173431734317343
# checkpointing_model with val loss: 1.8907640380906259
# Epoch: 2
# train_loss: 1.8921243871721438
# accuracy:0.3867924528301887
# checkpoint model with train loss: 1.8921243871721438
# val_loss
# model_state_dict
# val loss: 1.8907449728771377
# val accuracy: 0.3874538745387454
# checkpointing_model with val loss: 1.8907449728771377
# New Best Val Accuracy: 0.3874538745387454 with fusion: 0.0 and factor :2
# Epoch: 3
# train_loss: 1.9254792116421322
# accuracy:0.3757861635220126
# val_loss
# model_state_dict
# val loss: 1.9247631352660042
# val accuracy: 0.33579335793357934
# Epoch: 4
# train_loss: 1.9329011330660324
# accuracy:0.3977987421383648
# val_loss
# model_state_dict
# val loss: 1.9225503357151996
# val accuracy: 0.3284132841328413
# FUSION: 0.25
# Epoch: 0
# train_loss: 2.0373005975541676
# accuracy:0.37735849056603776
# checkpoint model with train loss: 2.0373005975541676
# val_loss
# model_state_dict
# val loss: 2.0183682564570393
# val accuracy: 0.3247232472324723
# Epoch: 1
# train_loss: 2.031179707541735
# accuracy:0.37264150943396224
# checkpoint model with train loss: 2.031179707541735
# val_loss
# model_state_dict
# val loss: 2.0091948758641847
# val accuracy: 0.36162361623616235
# Epoch: 2
# train_loss: 2.043995595687373
# accuracy:0.3522012578616352
# val_loss
# model_state_dict
# val loss: 2.0370486779287753
# val accuracy: 0.41697416974169743
# New Best Val Accuracy: 0.41697416974169743 with fusion: 0.25 and factor :2
# Epoch: 3
# train_loss: 2.036099881566861
# accuracy:0.3522012578616352
# val_loss
# model_state_dict
# val loss: 2.0060751328297264
# val accuracy: 0.36162361623616235
# Epoch: 4
# train_loss: 2.0417697851603664
# accuracy:0.39308176100628933
# val_loss
# model_state_dict
# val loss: 2.040699819184445
# val accuracy: 0.35793357933579334
# FUSION: 0.5
# Epoch: 0
# train_loss: 1.97194029992285
# accuracy:0.3946540880503145
# checkpoint model with train loss: 1.97194029992285
# val_loss
# model_state_dict
# val loss: 1.9947363193819516
# val accuracy: 0.36900369003690037
# Epoch: 1
# train_loss: 1.9760413664139724
# accuracy:0.3805031446540881
# val_loss
# model_state_dict
# val loss: 1.9963064047727346
# val accuracy: 0.3726937269372694
# Epoch: 2
# train_loss: 2.002283287894259
# accuracy:0.38207547169811323
# val_loss
# model_state_dict
# val loss: 1.9850267205538417
# val accuracy: 0.3173431734317343
# Epoch: 3
# train_loss: 2.016218022698684
# accuracy:0.3836477987421384
# val_loss
# model_state_dict
# val loss: 1.9929637999680578
# val accuracy: 0.36162361623616235
# Epoch: 4
# train_loss: 1.9924326078026344
# accuracy:0.3946540880503145
# val_loss
# model_state_dict
# val loss: 1.9641119321069327
# val accuracy: 0.33948339483394835
# FUSION: 0.75
# Epoch: 0
# train_loss: 2.0858159191151193
# accuracy:0.4009433962264151
# checkpoint model with train loss: 2.0858159191151193
# val_loss
# model_state_dict
# val loss: 2.1121457172539113
# val accuracy: 0.4022140221402214
# Epoch: 1
# train_loss: 2.0945455142459553
# accuracy:0.41352201257861637
# val_loss
# model_state_dict
# val loss: 2.0797783429534813
# val accuracy: 0.42066420664206644
# New Best Val Accuracy: 0.42066420664206644 with fusion: 0.75 and factor :2
# Epoch: 2
# train_loss: 2.0763749891640573
# accuracy:0.42138364779874216
# checkpoint model with train loss: 2.0763749891640573
# val_loss
# model_state_dict
# val loss: 2.083808263517772
# val accuracy: 0.3726937269372694
# Epoch: 3
# train_loss: 2.071812092079722
# accuracy:0.4056603773584906
# checkpoint model with train loss: 2.071812092079722
# val_loss
# model_state_dict
# val loss: 2.0872005374117735
# val accuracy: 0.4317343173431734
# New Best Val Accuracy: 0.4317343173431734 with fusion: 0.75 and factor :2
# Epoch: 4
# train_loss: 2.097959499401772
# accuracy:0.4119496855345912
# val_loss
# model_state_dict
# val loss: 2.049792704540567
# val accuracy: 0.36531365313653136
# FUSION: 1.0
# Epoch: 0
# train_loss: 1.9420526968896188
# accuracy:0.3270440251572327
# checkpoint model with train loss: 1.9420526968896188
# val_loss
# model_state_dict
# val loss: 1.9184261339038535
# val accuracy: 0.31365313653136534
# Epoch: 1
# train_loss: 1.92950872004357
# accuracy:0.3474842767295597
# checkpoint model with train loss: 1.92950872004357
# val_loss
# model_state_dict
# val loss: 1.9110317564458468
# val accuracy: 0.34317343173431736
# Epoch: 2
# train_loss: 1.9046951489493813
# accuracy:0.35062893081761004
# checkpoint model with train loss: 1.9046951489493813
# val_loss
# model_state_dict
# val loss: 1.9066709403851685
# val accuracy: 0.36900369003690037
# Epoch: 3
# train_loss: 1.9246882886716128
# accuracy:0.37735849056603776
# val_loss
# model_state_dict
# val loss: 1.9304352561036218
# val accuracy: 0.3948339483394834
# Epoch: 4
# train_loss: 1.9116876462224357
# accuracy:0.3553459119496855
# val_loss
# model_state_dict
# val loss: 1.9195319025232507
# val accuracy: 0.35793357933579334

# %%
fusion = 1.0
#original ratings
best_val_loss = 1000.0
best_train_loss = 1000.0
accur = 0
model = BiasedMatrixFactorization(interactions_train_orig.shape[0], interactions_train_orig.shape[1], mean, n_factors=4)
loss_func = torch.nn.MSELoss()
reg_loss_func = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=0.001)
for i in range(5):
    print ("Epoch: " + str(i))
    running_loss = 0.0
    accur = 0
    #best_train_loss = 1000.0
    for m, batch in enumerate(get_batch(batch_size, interactions_train_orig)):
        reg_loss_func.zero_grad()
        interactions = Variable(torch.FloatTensor(interactions_train_orig[batch,:].toarray()))
        rows = Variable(torch.LongTensor(batch))
        cols = Variable(torch.LongTensor(np.arange(interactions_train_orig.shape[1])))
        first = (contexts_full[batch,:].toarray())*fusion
        
        #contexts = Variable(torch.FloatTensor(contexts_full[batch,:].toarray()))
        contexts = Variable(torch.FloatTensor(first))
        
        predictions = model(rows, cols, contexts)
        
        loss = loss_func(predictions, interactions)
        running_loss += np.sqrt(loss.data[0])*batch_size
                
        correct = get_accuracy_test(interactions_train_orig, model, rows, fusion, contexts_full)
        #correct = get_accuracy_test(interactions_train_orig, model, rows, context_train)
        accur = accur + correct
                
        loss.backward()
    reg_loss_func.step()
    
    epoch_loss = running_loss/interactions_train_orig.shape[0]
    print ('train_loss: ' + str(epoch_loss))
            
    print ('accuracy:' + str(accur/len(checks[0])))
            
    if epoch_loss < best_train_loss:
        best_train_loss = epoch_loss
        print ('checkpoint model with train loss: ' + str(best_train_loss))
        checkpoint_model(epoch_loss, model, save_path_b)
        
    #val_loss, val_accuracy = run_validation(model,interactions_test_orig, context_train, batch_size, save_path)
    val_loss, val_accuracy = run_validation(model,interactions_test_orig, contexts_full, fusion, batch_size, save_path_b)
    print ('val loss: ' + str(val_loss))
    print ('val accuracy: ' + str(val_accuracy/len(checks_v[0])))
        
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        print ('checkpointing_model with val loss: ' + str(best_val_loss))
        checkpoint_model(val_loss, model, save_path_val_b)
# Out:
# Epoch: 0
# train_loss: 4.550172418345672
# accuracy:0.4229559748427673
# checkpoint model with train loss: 4.550172418345672
# val loss: 4.636757545310604
# val accuracy: 0.36531365313653136
# checkpointing_model with val loss: 4.636757545310604
# Epoch: 1
# train_loss: 4.615890558419431
# accuracy:0.4371069182389937
# val loss: 4.598108047392766
# val accuracy: 0.3763837638376384
# checkpointing_model with val loss: 4.598108047392766
# Epoch: 2
# train_loss: 4.635877704357542
# accuracy:0.4449685534591195
# val loss: 4.63508328878423
# val accuracy: 0.35424354243542433
# Epoch: 3
# train_loss: 4.621652008879292
# accuracy:0.4229559748427673
# val loss: 4.627915499152715
# val accuracy: 0.3837638376383764
# Epoch: 4
# train_loss: 4.583118679920118
# accuracy:0.41509433962264153
# val loss: 4.632746507668794
# val accuracy: 0.34686346863468637
